# %% [markdown]
# # BLOCKWISE: Wrangling the LOCATION_CRIME VIEW IN POSTGRES
#
# ## Exploratory Analysis with ```Pandas```
#
# You may also find these resources helpful:
# https://www.analyticsvidhya.com/blog/2016/01/complete-tutorial-learn-data-science-python-scratch-2/
# https://chrisalbon.com/python/pandas_dataframe_descriptive_stats.html
#
# The Titanic

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import psycopg2

# %matplotlib inline

# %% [markdown]
# ## Load the Data
# The file we'll be exploring today, ```train.csv```, represents a subset of the Titanic's passenger manifest. It was downloaded when you cloned X503's GitHub repo and is located in the ```Data``` folder. The remaining data from the passenger manifest is in ```test.csv```, which is saved in the same folder and we'll use later on in the Machine Learning course. But for now, let's load the ```train.csv``` file and start exploring the data.
#
# => Load the ```train.csv``` file into a ```pandas``` ```DataFrame```.
#
# Documentation: http://pandas.pydata.org/pandas-docs/stable/generated/pandas.read_csv.html

# %%
conn_str = "host={} dbname={} user={} password={}".format('localhost', 'blockwise', 'postgres', 'purplerain')
conn = psycopg2.connect(conn_str)
df = pd.read_sql_query('select * from "location_crime"',conn)

# %% [markdown]
# ## Exploring the Data

# %% [markdown]
# => Use ```pandas``` to view the "head" of the file with the first 10 rows.
#
# Documentation: http://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.head.html

# %%
# Use pandas to view the first 10 rows of the file.
df.head(100)
# Out:
#         business_name                    address  \
# 0         All Purpose          79 Potomac Ave SE
# 1         All Purpose          79 Potomac Ave SE
# 2               Ambar              523 8th St SE
# 3               Ambar              523 8th St SE
# 4               Ambar              523 8th St SE
# 5               Ambar              523 8th St SE
# 6               Ambar              523 8th St SE
# 7               Ambar              523 8th St SE
# 8               Ambar              523 8th St SE
# 9               Ambar              523 8th St SE
# 10              Ambar              523 8th St SE
# 11              Ambar              523 8th St SE
# 12              Ambar              523 8th St SE
# 13              Ambar              523 8th St SE
# 14              Ambar              523 8th St SE
# 15              Ambar              523 8th St SE
# 16              Ambar              523 8th St SE
# 17              Ambar              523 8th St SE
# 18              Ambar              523 8th St SE
# 19              Ambar              523 8th St SE
# 20              Ambar              523 8th St SE
# 21              Ambar              523 8th St SE
# 22              Ambar              523 8th St SE
# 23              Ambar              523 8th St SE
# 24              Ambar              523 8th St SE
# 25              Ambar              523 8th St SE
# 26              Ambar              523 8th St SE
# 27              Ambar              523 8th St SE
# 28              Ambar              523 8th St SE
# 29              Ambar              523 8th St SE
# ..                ...                        ...
# 70  b DC Penn Quarter    801 Pennsylvania Ave NW
# 71  b DC Penn Quarter    801 Pennsylvania Ave NW
# 72  b DC Penn Quarter    801 Pennsylvania Ave NW
# 73  b DC Penn Quarter    801 Pennsylvania Ave NW
# 74  b DC Penn Quarter    801 Pennsylvania Ave NW
# 75  b DC Penn Quarter    801 Pennsylvania Ave NW
# 76  b DC Penn Quarter    801 Pennsylvania Ave NW
# 77  b DC Penn Quarter    801 Pennsylvania Ave NW
# 78  b DC Penn Quarter    801 Pennsylvania Ave NW
# 79  b DC Penn Quarter    801 Pennsylvania Ave NW
# 80  b DC Penn Quarter    801 Pennsylvania Ave NW
# 81  b DC Penn Quarter    801 Pennsylvania Ave NW
# 82  b DC Penn Quarter    801 Pennsylvania Ave NW
# 83  b DC Penn Quarter    801 Pennsylvania Ave NW
# 84  b DC Penn Quarter    801 Pennsylvania Ave NW
# 85  b DC Penn Quarter    801 Pennsylvania Ave NW
# 86  b DC Penn Quarter    801 Pennsylvania Ave NW
# 87  b DC Penn Quarter    801 Pennsylvania Ave NW
# 88  b DC Penn Quarter    801 Pennsylvania Ave NW
# 89  b DC Penn Quarter    801 Pennsylvania Ave NW
# 90        Bandit Taco  1946 New Hampshire Ave NW
# 91        Bandit Taco  1946 New Hampshire Ave NW
# 92        Bandit Taco  1946 New Hampshire Ave NW
# 93        Bandit Taco  1946 New Hampshire Ave NW
# 94        Bandit Taco  1946 New Hampshire Ave NW
# 95        Bandit Taco  1946 New Hampshire Ave NW
# 96        Bandit Taco  1946 New Hampshire Ave NW
# 97        Bandit Taco  1946 New Hampshire Ave NW
# 98        Bandit Taco  1946 New Hampshire Ave NW
# 99        Bandit Taco  1946 New Hampshire Ave NW
#
#                                            block                     offense  \
# 0              1 - 99 block of potomac avenue se                theft f/auto
# 1              1 - 99 block of potomac avenue se                 theft/other
# 2               500 - 699 block of 8th street se  assault w/dangerous weapon
# 3               500 - 699 block of 8th street se                    burglary
# 4               500 - 699 block of 8th street se                    burglary
# 5               500 - 699 block of 8th street se                    burglary
# 6               500 - 699 block of 8th street se                    burglary
# 7               500 - 699 block of 8th street se                    burglary
# 8                  1 - 99 block of 8th street se         motor vehicle theft
# 9               500 - 699 block of 8th street se         motor vehicle theft
# 10              500 - 699 block of 8th street se         motor vehicle theft
# 11                 1 - 99 block of 8th street se                     robbery
# 12              500 - 699 block of 8th street se                theft f/auto
# 13              500 - 699 block of 8th street se                theft f/auto
# 14              500 - 699 block of 8th street se                theft f/auto
# 15              500 - 699 block of 8th street se                theft f/auto
# 16                 1 - 99 block of 8th street se                theft f/auto
# 17                 1 - 99 block of 8th street se                theft f/auto
# 18                 1 - 99 block of 8th street se                theft f/auto
# 19              500 - 699 block of 8th street se                 theft/other
# 20              500 - 699 block of 8th street se                 theft/other
# 21              500 - 699 block of 8th street se                 theft/other
# 22              500 - 699 block of 8th street se                 theft/other
# 23              500 - 699 block of 8th street se                 theft/other
# 24              500 - 699 block of 8th street se                 theft/other
# 25              500 - 699 block of 8th street se                 theft/other
# 26              500 - 699 block of 8th street se                 theft/other
# 27              500 - 699 block of 8th street se                 theft/other
# 28              500 - 699 block of 8th street se                 theft/other
# 29              500 - 699 block of 8th street se                 theft/other
# ..                                           ...                         ...
# 70     700 - 899 block of pennsylvania avenue nw                 theft/other
# 71     700 - 899 block of pennsylvania avenue nw                 theft/other
# 72     700 - 899 block of pennsylvania avenue nw                 theft/other
://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.median.html

# %%
# Use pandas to get the median of the Age column. DataFrame.median(axis=None, skipna=None, level=None, numeric_only=None, **kwargs)[source]
df['year'].median()
# Out:
# 2017.0

# %% [markdown]
# __=>__ Use ```pandas``` to find the number of unique values in the ```Ticket``` column.
#
# Documentation: http://pandas.pydata.org/pandas-docs/stable/generated/pandas.Series.nunique.html

# %%
# Use pandas to find the number of unique values in the Ticket column. Series.nunique(dropna=True)[source]¶
df['year'].nunique()
#df.dtypes
# Out:
# 3

# %% [markdown]
# The ```Ticket``` column has a large number of unique values. As we saw above in our initial exploration of the data, this feature includes a combination of text and numerical data. Therefore, let's use ```value_counts()``` to generate a frequency distribution of the ```Ticket``` values, so we can see whether this data will be useful for our models.
#
# __=>__ Use ```pandas``` to count the number of each unique value in the ```Ticket``` column.
#
# Documentation: http://pandas.pydata.org/pandas-docs/version/0.20.3/generated/pandas.Series.value_counts.html

# %%
# Use pandas to count the number of each unique Ticket value.
df['year'].value_counts()
# Out:
# 2017    33069
# 2016    27788
# 2018     8347
# Name: year, dtype: int64

# %% [markdown]
# ## Visualize the Data
# Now let's look at two histograms of the ```Fare``` data. In the first, we'll set ```bins=10``` and in the second ```bin=50```. Which one do you find the most helpful? What are you able to tell about the range of fares paid by the passengers from the histograms?

# %%
fig = plt.figure(figsize=(7,10))
ax = fig.add_subplot(211)
ax.hist(df['year'], bins=10, range=(df['year'].min(),df['year'].max()))
plt.title('Year Distribution with 10 Bins')
plt.xlabel('year')
plt.ylabel('offense')
plt.show()

fig = plt.figure(figsize=(7,10))
ax = fig.add_subplot(212)
ax.hist(df['year'], bins=5, range=(df['year'].min(),df['year'].max()))
plt.title('Year Distribution with 5 Bins')
plt.xlabel('year')
plt.ylabel('Count of Offenses')
plt.show()

# %% [markdown]
# ## Data Wrangling
# It's important to wrangle your data before building your models, since ```scikit-learn``` cannot process missing values and only accepts numerical data. Outliers should also be dealt with beforehand, since they will negatively impact the performance of most machine learning models.

# %% [markdown]
# ### Outliers
# When examining the histograms of the ```Fare``` data, did you notice any potential outliers? Since there is a relationship between the cost of a ticket and the class the passenger was traveling in, let's look at a box plot of this data to investigate further.

# %%
f, ax = plt.subplots(figsize=(9,7))
sns.boxplot(x='Pclass', y='Fare', data=df, palette='vlag')
sns.swarmplot(x='Pclass', y='Fare', data=df, size=2, color='0.3')
plt.title('Ticket Cost By Class', size=14)
plt.xlabel('Ticket Class', size=12)
plt.ylabel('Fares', size=12)
plt.show()

# %% [markdown]
# We can quickly see that there a few first-class fares that are much higher than the others. Let's sort the data set by the ```Fare``` column so we can see the cost of the most expensive tickets.

# %%
df.sort_values(by='year', ascending=False).head(5)
# Out:
#               business_name                   address  \
# 1189         Federalist Pig       1654 Columbia Rd NW
# 1773                 Stable              1324 H St NE
# 1261  Founding Farmers - DC  1924 Pennsylvania Ave NW
# 1260  Founding Farmers - DC  1924 Pennsylvania Ave NW
# 1256  Founding Farmers - DC  1924 Pennsylvania Ave NW
#
#                                             block       offense offense_group  \
# 1189        1646 - 1699 block of columbia road nw   theft/other      property
# 1773             1300 - 1399 block of h street ne      burglary      property
# 1261  1900 - 1999 block of pennsylvania avenue nw   theft/other      property
# 1260  1900 - 1999 block of pennsylvania avenue nw   theft/other      property
# 1256  1900 - 1999 block of pennsylvania avenue nw  theft f/auto      property
#
#       year               report_date
# 1189  2018  2018-04-06T01:56:56.000Z
# 1773  2018  2018-02-13T17:45:14.000Z
# 1261  2018  2018-01-17T14:09:06.000Z
# 1260  2018  2018-01-23T16:39:47.000Z
# 1256  2018  2018-01-18T03:15:52.000Z

# %% [markdown]
# Since the ```$512``` fares appear to be outliers, let's replace them with ```$213```, since it is the second highest value and much closer to the other data points.

# %%
for idx in df.index:
    if df.loc[idx].year > 2016:
        df.set_value(idx, 'year', 263.0000)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-429fd6382bdc> in <module>()
#       1 for idx in df.index:
# ----> 2     if df.loc[idx].year > 2016:
#       3         df.set_value(idx, 'year', 263.0000)
#
# TypeError: '>' not supported between instances of 'str' and 'int'

# %% [markdown]
# ### Dealing with Missing Data
# When deciding how to handle missing values, it is important to know how prevalent they are in your data. Let's use ```pandas``` to find out how many ```Cabin``` values are missing from our data set.
#
# __=>__ Use ```pandas``` to get the sum of all the null values in the ```Cabin``` column.
#
# Documentation:
# http://pandas.pydata.org/pandas-docs/stable/generated/pandas.isnull.html
# http://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.sum.html

# %%
# Sum the number of null Cabin values.

# %% [markdown]
# ### Deleting a Feature
#
#
# __=>__ Since most of the ```Cabin``` values are missing, let's use ```pandas``` to drop the column. We will also drop the ```Ticket``` column, since as we saw earlier, it contains of a mix of text and numeric data that doesn't appear to contain any useful information. *HINT: remember to set ```axis=1```.*
#
# Documentation:
# http://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.drop.html
# https://chrisalbon.com/python/pandas_dropping_column_and_rows.html

# %%
# Use pandas to drop the Cabin and Ticket columns.

# %% [markdown]
# ### Filling in Missing Data
# While the ```Age``` column also contains null values, it is missing far fewer than the ```Cabin``` column, so we will fill those in rather than drop the column. The simplest approach, which we'll use here, is to replace the null values with the mean age of the passengers.
#
# __=>__ First use ```pandas``` to calculate and save the mean age of the passengers. Then replace the null values in the ```Age``` column with that number.
#
# Documentation:
# http://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.mean.html
# http://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.fillna.html

# %%
# First, use pandas to find the mean age of the passengers: mean_age
mean_age = df['year']

# ...and then fill in the null Age values with mean_age.

# %%
# Check that there are no more null values in the Age column.

# %% [markdown]
# ### Save Your Work
# ...you will need it in a few weeks!

# %%
import pandas.io.sql as pd_sql
import sqlite3 as sql

# Create a sqlite3 database to store the data.
con = sql.connect('titanic.db')

# %% [markdown]
# __=>__ Use ```pandas``` to write your ```DataFrame``` to the ```sqlite``` database.
#
# Documenation: http://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.to_sql.html

# %%
# Use pandas to save your dataframe to a sqlite database name 'training_data'.
