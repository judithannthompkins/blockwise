# %% [markdown]
# This Notebook is based first on adapting the code on the following web page to explore our DC crime data:
#
# http://pbpython.com/simple-graphing-pandas.html

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pprint
pd.__version__
# Out:
# '0.22.0'

# %%
# %matplotlib inline

# %%
crimes=pd.read_csv("dc_crime2018423.csv",parse_dates=['START_DATE'])
crimes.head()
# Out:
#   NEIGHBORHOOD_CLUSTER  CENSUS_TRACT offensegroup  LONGITUDE  \
# 0           cluster 32        7708.0     property -76.955521
# 1            cluster 4         100.0     property -77.059614
# 2           cluster 23        8904.0     property -76.981924
# 3           cluster 29        9601.0      violent -76.937531
# 4           cluster 25       10600.0      violent -76.995538
#
#                   END_DATE         offense-text     SHIFT    YBLOCK  DISTRICT  \
# 0  2016-10-04T16:37:29.000  motor vehicle theft   evening  135396.0       6.0
# 1  2016-10-04T17:44:13.000          theft/other   evening  137194.0       2.0
# 2  2016-10-04T20:10:43.000          theft/other   evening  136987.0       5.0
# 3  2016-10-14T00:12:56.000              robbery  midnight  138092.0       6.0
# 4  2016-10-22T16:40:05.000              robbery   evening  137463.0       5.0
#
#    WARD    ...        XBLOCK                                     BLOCK  \
# 0     7    ...      403859.0  3500 - 3526 block of minnesota avenue se
# 1     2    ...      394829.0          3000 - 3029 block of k street nw
# 2     5    ...      401568.0   1500 - 1599 block of maryland avenue ne
# 3     7    ...      405418.0        1500 1535  block of 45th street ne
# 4     6    ...      400387.0      700 - 799 block of florida avenue ne
#
#            START_DATE       CCN              OFFENSE  ANC  \
# 0 2016-10-04 16:09:08  16168699  motor vehicle theft   7B
# 1 2016-10-04 17:00:48  16168738          theft/other   2E
# 2 2016-10-04 19:21:09  16168845          theft/other   5D
# 3 2016-10-13 22:45:39  16174401              robbery   7D
# 4 2016-10-22 16:24:12  16180021              robbery   6C
#
#                  REPORT_DAT  METHOD                                location  \
# 0  2016-10-05T03:00:47.000Z  others  38.886402972929169,-76.955523453842957
# 1  2016-10-05T01:36:11.000Z  others  38.902593275715809,-77.059616752356732
# 2  2016-10-05T02:21:19.000Z  others  38.900742359981244,-76.981925885322667
# 3  2016-10-14T05:31:03.000Z     gun  38.910681288493713,-76.937533164068512
# 4  2016-10-22T22:55:30.000Z     gun   38.90503165003841,-76.995540557600265
#
#     LATITUDE
# 0  38.886395
# 1  38.902585
# 2  38.900735
# 3  38.910673
# 4  38.905024
#
# [5 rows x 28 columns]

# %%
crimes.describe()
# Out:
#        CENSUS_TRACT     LONGITUDE         YBLOCK      DISTRICT          WARD  \
# count  68891.000000  69047.000000   69047.000000  69024.000000  69047.000000
# mean    6239.901439    -77.007812  137643.004474      3.666435      4.413153
# std     3109.058330      0.035928    3357.622141      1.952688      2.342396
# min      100.000000    -77.113642  127300.000000      1.000000      1.000000
# 25%     3600.000000    -77.031223  136128.000000      2.000000      2.000000
# 50%     6900.000000    -77.012913  137611.000000      3.000000      5.000000
# 75%     8904.000000    -76.985512  139596.000000      5.000000      6.000000
# max    11100.000000    -76.910021  147292.000000      7.000000      8.000000
#
#                YEAR           PSA      ucr-rank         XBLOCK           CCN  \
# count  69047.000000  69018.000000  69047.000000   69047.000000  6.904700e+04
# mean    2016.734992    371.193862      6.052892  399322.959791  1.685932e+07
# std        0.671448    195.087980      1.300240    3116.131280  7.476037e+05
# min     2016.000000    101.000000      1.000000  390147.000000  2.111617e+06
# 25%     2016.000000    206.000000      6.000000  397293.000000  1.616979e+07
# 50%     2017.000000    308.000000      6.000000  398880.000000  1.705153e+07
# 75%     2017.000000    506.000000      7.000000  401257.000000  1.717364e+07
# max     2018.000000    708.000000      9.000000  407806.000000  8.501717e+07
#
#            LATITUDE
# count  69047.000000
# mean      38.906640
# std        0.030245
# min       38.813471
# 25%       38.892979
# 50%       38.906338
# 75%       38.924239
# max       38.993560

# %%
crimes['ucr-rank'].describe()
# Out:
# count    69047.000000
# mean         6.052892
# std          1.300240
# min          1.000000
# 25%          6.000000
# 50%          6.000000
# 75%          7.000000
# max          9.000000
# Name: ucr-rank, dtype: float64

# %%
crimes.dtypes
# Out:
# NEIGHBORHOOD_CLUSTER            object
# CENSUS_TRACT                   float64
# offensegroup                    object
# LONGITUDE                      float64
# END_DATE                        object
# offense-text                    object
# SHIFT                           object
# YBLOCK                         float64
# DISTRICT                       float64
# WARD                             int64
# YEAR                             int64
# offensekey                      object
# BID                             object
# sector                          object
# PSA                            float64
# ucr-rank                         int64
# BLOCK_GROUP                     object
# VOTING_PRECINCT                 object
# XBLOCK                         float64
# BLOCK                           object
# START_DATE              datetime64[ns]
# CCN                              int64
# OFFENSE                         object
# ANC                             object
# REPORT_DAT                      object
# METHOD                          object
# location                        object
# LATITUDE                       float64
# dtype: object

# %%
crimetypes = crimes[['WARD','offensegroup','offense-text','offensekey','ucr-rank','OFFENSE','METHOD','START_DATE']]
crimetypes.head()
# Out:
#    WARD offensegroup         offense-text                    offensekey  \
# 0     7     property  motor vehicle theft  property|motor vehicle theft
# 1     2     property          theft/other          property|theft/other
# 2     5     property          theft/other          property|theft/other
# 3     7      violent              robbery               violent|robbery
# 4     6      violent              robbery               violent|robbery
#
#    ucr-rank              OFFENSE  METHOD          START_DATE
# 0         8  motor vehicle theft  others 2016-10-04 16:09:08
# 1         6          theft/other  others 2016-10-04 17:00:48
# 2         6          theft/other  others 2016-10-04 19:21:09
# 3         4              robbery     gun 2016-10-13 22:45:39
# 4         4              robbery     gun 2016-10-22 16:24:12

# %%
offense_group = crimetypes.groupby('OFFENSE')
offense_group.size()
# Out:
# OFFENSE
# arson                             9
# assault w/dangerous weapon     3943
# burglary                       3471
# homicide                        256
# motor vehicle theft            5083
# robbery                        4789
# sex abuse                       619
# theft f/auto                  22093
# theft/other                   28784
# dtype: int64

# %%
ucr_avg = offense_group.mean()
ucr_avg.sort_values(by='ucr-rank').head()
# Out:
#                                 WARD  ucr-rank
# OFFENSE
# homicide                    6.359375       1.0
# sex abuse                   5.037157       2.0
# assault w/dangerous weapon  5.654324       3.0
# robbery                     5.045939       4.0
# burglary                    4.965140       5.0

# %%
my_plot = ucr_avg.plot(kind='bar')

# %%
my_plot = ucr_avg.sort_values(by='ucr-rank',ascending=False).plot(kind='bar',legend=None,title="Average UCR Rank by Offense")
my_plot.set_xlabel("Offense")
my_plot.set_ylabel("UCR Rank (1-9)")
# Out:
# Text(0,0.5,'UCR Rank (1-9)')

# %%
crimetypes = crimes[['offensegroup','WARD','ucr-rank','START_DATE']]
crimetypes.head()
# Out:
#   offensegroup  WARD  ucr-rank          START_DATE
# 0     property     7         8 2016-10-04 16:09:08
# 1     property     2         6 2016-10-04 17:00:48
# 2     property     5         6 2016-10-04 19:21:09
# 3      violent     7         4 2016-10-13 22:45:39
# 4      violent     6         4 2016-10-22 16:24:12

# %%
ward_group=crimetypes.groupby(['offensegroup','WARD']).mean()

# %%
ward_group.head(20)
# Out:
#                    ucr-rank
# offensegroup WARD
# property     1     6.551977
#              2     6.377454
#              3     6.426696
#              4     6.591125
#              5     6.517702
#              6     6.455884
#              7     6.572192
#              8     6.437781
# violent      1     3.538608
#              2     3.398438
#              3     3.456790
#              4     3.475032
#              5     3.360337
#              6     3.482959
#              7     3.352701
#              8     3.229736

# %%
ward_group.unstack().head()
# Out:
#               ucr-rank                                                    \
# WARD                 1         2         3         4         5         6
# offensegroup
# property      6.551977  6.377454  6.426696  6.591125  6.517702  6.455884
# violent       3.538608  3.398438  3.456790  3.475032  3.360337  3.482959
#
#
# WARD                 7         8
# offensegroup
# property      6.572192  6.437781
# violent       3.352701  3.229736

# %%
my_plot = ward_group.unstack().plot(kind='bar',stacked=True,title="UCR by Ward")
my_plot.set_xlabel("Wards")
my_plot.set_ylabel("Average UCR Rank")
# Out:
# Text(0,0.5,'Average UCR Rank')

# %%
my_plot = ward_group.unstack().plot(kind='bar',stacked=True,title="Average UCR Rank by Ward",figsize=(9, 7))
my_plot.set_xlabel("Wards")
my_plot.set_ylabel("Average UCR Rank")
my_plot.legend(["Average","Ward 1","Ward2","Ward 3","Ward 4","Ward 5"], loc=9,ncol=6)

# %%
crime_patterns = crimes[['ucr-rank','START_DATE']]
crime_patterns.head()
# Out:
#    ucr-rank          START_DATE
# 0         8 2016-10-04 16:09:08
# 1         6 2016-10-04 17:00:48
# 2         6 2016-10-04 19:21:09
# 3         4 2016-10-13 22:45:39
# 4         4 2016-10-22 16:24:12

# %%
crime_plot = crime_patterns['ucr-rank'].hist(bins=9)
crime_plot.set_title("Crime Patterns")
crime_plot.set_xlabel("Average UCR Ranks (1-9)")
crime_plot.set_ylabel("Number of Crimes")
# Out:
# Text(0,0.5,'Number of Crimes')

# %%
crime_patterns = crimes[['ucr-rank','START_DATE']]
crime_patterns.head(10)
# Out:
#    ucr-rank          START_DATE
# 0         8 2016-10-04 16:09:08
# 1         6 2016-10-04 17:00:48
# 2         6 2016-10-04 19:21:09
# 3         4 2016-10-13 22:45:39
# 4         4 2016-10-22 16:24:12
# 5         7 2016-10-22 20:21:52
# 6         6 2016-10-22 21:53:20
# 7         7 2016-10-23 01:30:55
# 8         7 2016-10-22 09:00:04
# 9         7 2016-11-01 08:30:07

# %%
crime_patterns.tail(20)
# Out:
#        ucr-rank          START_DATE
# 69027         7 2018-01-22 19:54:09
# 69028         8 2018-01-22 16:00:08
# 69029         7 2018-01-22 19:00:12
# 69030         4 2018-01-22 21:57:36
# 69031         4 2018-01-22 23:24:22
# 69032         3 2018-01-23 00:00:05
# 69033         7 2018-01-22 19:30:34
# 69034         6 2018-01-17 16:30:20
# 69035         7 2018-02-04 16:00:41
# 69036         6 2018-04-22 15:42:27
# 69037         6 2018-04-22 18:52:40
# 69038         6 2018-04-22 18:59:44
# 69039         6 2018-04-22 19:30:48
# 69040         6 2018-04-22 20:52:44
# 69041         6 2018-04-21 00:55:47
# 69042         6 2018-04-19 10:29:27
# 69043         4 2018-04-22 03:45:50
# 69044         7 2018-04-22 08:31:38
# 69045         5 2018-04-22 04:35:12
# 69046         7 2018-04-22 13:20:01

# %%
#Doesn't work for some reason
crime_patterns = crime_patterns.set_index('START_DATE')
crime_patterns.tail(12)
# Out:
#                      ucr-rank
# START_DATE
# 2018-02-04 16:00:41         7
# 2018-04-22 15:42:27         6
# 2018-04-22 18:52:40         6
# 2018-04-22 18:59:44         6
# 2018-04-22 19:30:48         6
# 2018-04-22 20:52:44         6
# 2018-04-21 00:55:47         6
# 2018-04-19 10:29:27         6
# 2018-04-22 03:45:50         4
# 2018-04-22 08:31:38         7
# 2018-04-22 04:35:12         5
# 2018-04-22 13:20:01         7

# %%
#Changing the sampling to year instead of month
crime_patterns.tail(200).resample('A',how=sum)
# Out:
# C:\Users\Judith\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: how in .resample() is deprecated
# the new syntax is .resample(...)..apply(<func>)
#             ucr-rank
# START_DATE
# 2017-12-31        14
# 2018-12-31      1211

# %%
crime_patterns.resample('Y').mean() #not working for year end
crime_patterns.tail(12)
# Out:
#                      ucr-rank
# START_DATE
# 2018-02-04 16:00:41         7
# 2018-04-22 15:42:27         6
# 2018-04-22 18:52:40         6
# 2018-04-22 18:59:44         6
# 2018-04-22 19:30:48         6
# 2018-04-22 20:52:44         6
# 2018-04-21 00:55:47         6
# 2018-04-19 10:29:27         6
# 2018-04-22 03:45:50         4
# 2018-04-22 08:31:38         7
# 2018-04-22 04:35:12         5
# 2018-04-22 13:20:01         7

# %% [markdown]
# #try this - doesn't work
# #https://stackoverflow.com/questions/41517127/python-pandas-resample-date-range?utm_medium=organic&utm_source=google_rich_qa&utm_campaign=google_rich_qa
# date_range = crime_patterns(start = '5/3/2005', periods =5+1, freq='1D')
# new_date_range = crime_patterns.date_range(date_range.min(), date_range.max(), freq='30 min')

# %%
crime_plot = crime_patterns.resample('M',how=sum).plot(title="Average UCR Rank by Month",legend=None)
crime_plot.tail(10)
# Out:
# C:\Users\Judith\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: how in .resample() is deprecated
# the new syntax is .resample(...)..apply(<func>)
#   """Entry point for launching an IPython kernel.
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-39-6479802976e8> in <module>()
#       1 crime_plot = crime_patterns.resample('M',how=sum).plot(title="Average UCR Rank by Month",legend=None)
# ----> 2 crime_plot.tail(10)
#
# AttributeError: 'AxesSubplot' object has no attribute 'tail'

# %%
import psycopg2

# %%
con = psycopg2.connect("dbname='blockwise' user='postgres' password='purplerain'")
cur = con.cursor()

# %%
SQL = "SELECT * FROM location_crime;"
cur.execute(SQL)
rows = cur.fetchall()
con.close()

# %%
pprint.pprint(rows)
# Out:
# [('Barrel',
#   '613 Pennsylvania Ave SE',
#   'American (New)',
#   Decimal('4.5'),
#   '600 - 669 block of pennsylvania avenue se',
#   'assault w/dangerous weapon',
#   'violent',
#   'gun',
#   '3',
#   '2018',
#   '2018-01-21T06:17:06.000Z'),
#  ('Barrel',
#   '613 Pennsylvania Ave SE',
#   'American (New)',
#   Decimal('4.5'),
#   '600 - 669 block of pennsylvania avenue se',
#   
000Z'),
#  ('Unconventional Diner',
#   '1207 9th St NW',
#   'Diners',
#   Decimal('4.5'),
#   '1200 - 1299 block of 9th street nw',
#   'theft/other',
#   'property',
#   'others',
#   '6',
#   '2017',
#   '2017-07-18T04:09:10.000Z'),
#  ('Unconventional Diner',
#   '1207 9th St NW',
#   'Diners',
#   Decimal('4.5'),
#   '1200 - 1299 block of 9th street nw',
#   'theft/other',
#   'property',
#   'others',
#   '6',
#   '2017',
#   '2017-05-08T18:39:09.000Z'),
#  ('Unconventional Diner',
#   '1207 9th St NW',
#   'Diners',
#   Decimal('4.5'),
#   '1200 - 1299 block of 9th street nw',
#   'theft/other',
#   'property',
#   'others',
#   '6',
#   '2017',
#   '2017-02-06T11:10:24.000Z'),
#  ('Unconventional Diner',
#   '1207 9th St NW',
#   'Diners',
#   Decimal('4.5'),
#   '1200 - 1299 block of 9th street nw',
#   'theft/other',
#   'property',
#   'others',
#   '6',
#   '2017',
#   '2017-01-13T04:25:00.000Z'),
#  ('Unconventional Diner',
#   '1207 9th St NW',
#   'Diners',
#   Decimal('4.5'),
#   '1200 - 1299 block of 9th street nw',
#   'theft/other',
#   'property',
#   'others',
#   '6',
#   '2016',
#   '2016-10-22T06:40:55.000Z'),
#  ('Unconventional Diner',
#   '1207 9th St NW',
#   'Diners',
#   Decimal('4.5'),
#   '1200 - 1299 block of 9th street nw',
#   'theft/other',
#   'property',
#   'others',
#   '6',
#   '2016',
#   '2016-07-27T20:52:03.000Z'),
#  ('Unconventional Diner',
#   '1207 9th St NW',
#   'Diners',
#   Decimal('4.5'),
#   '1200 - 1299 block of 9th street nw',
#   'theft/other',
#   'property',
#   'others',
#   '6',
#   '2016',
#   '2016-07-16T00:41:51.000Z'),
#  ('Unconventional Diner',
#   '1207 9th St NW',
#   'Diners',
#   Decimal('4.5'),
#   '1200 - 1299 block of 9th street nw',
#   'theft/other',
#   'property',
#   'others',
#   '6',
#   '2016',
#   '2016-04-21T17:40:46.000Z')]

# %%
for row in rows:  
    print("Business Name: ", row[0], "Category: ", row[2], "Rating: ", row[3], "Block: ", row[4], "Offense: ", row[5], "Offense Group: ", row[6])
# Out:
# Business Name:  Barrel Category:  American (New) Rating:  4.5 Block:  600 - 669 block of pennsylvania avenue se Offense:  assault w/dangerous weapon Offense Group:  violent
# Business Name:  Barrel Category:  American (New) Rating:  4.5 Block:  600 - 669 block of pennsylvania avenue se Offense:  assault w/dangerous weapon Offense Group:  violent
# Business Name:  Barrel Category:  American (New) Rating:  4.5 Block:  600 - 669 block of pennsylvania avenue se Offense:  assault w/dangerous weapon Offense Group:  violent
# Business Name:  Barrel Category:  American (New) Rating:  4.5 Block:  600 - 669 block of pennsylvania avenue se Offense:  burglary Offense Group:  property
# Business Name:  Barrel Category:  American (New) Rating:  4.5 Block:  600 - 669 block of pennsylvania avenue se Offense:  burglary Offense Group:  property
# Business Name:  Barrel Category:  American (New) Rating:  4.5 Block:  600 - 669 block of pennsylvania avenue se Offense:  burglary Offense Group:  property
# Business Name:  Barrel Category:  American (New) Rating:  4.5 Block:  600 - 669 block of pennsylvania avenue se Offense:  burglary Offense Group:  property
# Business Name:  Barrel Category:  American (New) Rating:  4.5 Block:  600 - 669 block of pennsylvania avenue se Offense:  motor vehicle theft Offense Group:  property
# Business Name:  Barrel Category:  American (New) Rating:  4.5 Block:  600 - 669 block of pennsylvania avenue se Offense:  motor vehicle theft Offense Group:  property
# Business Name:  Barrel Category:  American (New) Rating:  4.5 Block:  600 - 669 block of pennsylvania avenue se Offense:  robbery Offense Group:  violent
# Business Name:  Barrel Category:  American (New) Rating:  4.5 Block:  600 - 669 block of pennsylvania avenue se Offense:  robbery Offense Group:  violent
# Business Name:  Barrel Category:  American (New) Rating:  4.5 Block:  600 - 669 block of pennsylvania avenue se Offense:  robbery Offense Group:  violent
# Business Name:  Barrel Category:  American (New) Rating:  4.5 Block:  600 - 669 block of pennsylvania avenue se Offense:  robbery Offense Group:  violent
# Business Name:  Barrel Category:  American (New) Rating:  4.5 Block:  600 - 669 block of pennsylvania avenue se Offense:  robbery Offense Group:  violent
# Business Name:  Barrel Category:  American (New) Rating:  4.5 Block:  600 - 669 block of pennsylvania avenue se Offense:  robbery Offense Group:  violent
# Business Name:  Barrel Category:  American (New) Rating:  4.5 Block:  600 - 669 block of pennsylvania avenue se Offense:  robbery Offense Group:  violent
# Business Name:  Barrel Category:  American (New) Rating:  4.5 Block:  600 - 669 block of pennsylvania avenue se Offense:  robbery Offense Group:  violent
# Business Name:  Barrel Category:  American (New) Rating:  4.5 Block:  600 - 669 block of pennsylvania avenue se Offense:  theft f/auto Offense Group:  property
# Business Name:  Barrel Category:  American (New) Rating:  4.5 Block:  600 - 669 block of pennsylvania avenue se Offense:  theft f/auto Offense Group:  property
# Business Name:  Barrel Category:  American (New) Rating:  4.5 Block:  600 - 669 block of pennsylvania avenue se Offense:  theft f/auto Offense Group:  property
# Business Name:  Barrel Category:  American (New) Rating:  4.5 Block:  600 - 669 block of pennsylvania avenue se Offense:  theft f/auto Offense Group:  property
# Business Name:  Barrel Category:  American (New) Rating:  4.5 Block:  600 - 669 block of pennsylvania avenue se Offense:  theft f/auto Offense Group:  property
# Business Name:  Barrel Category:  American (New) Rating:  4.5 Block:  600 - 669 block of pennsylvania avenue se Offense:  theft f/auto Offense Group:  property
# Business Name:  Barrel Category:  American (New) Rating:  4.5 Block:  600 - 669 block of pennsylvania avenue se Offense:  theft/other Offense Group:  property
# Business Name:  Barrel Category:  American (New) Rating:  4.5 Block:  600 - 669 block of pennsylvania avenue se Offense:  theft/other Offense Group:  property
# Business Name:  Barrel Category:  American (New) Rating:  4.5 Block:  600 - 669 block of pennsylvania avenue se Offense:  theft/other Offense Group:  property
# Business Name:  Barrel Category:  American (New) Rating:  4.5 Block:  600 - 669 block of pennsylvania avenue se Offense:  theft/other Offense Group:  property
# Business Name:  Barrel Category:  American (New) Rating:  4.5 Block:  600 - 669 block of pennsylvania avenue se Offense:  theft/other Offense Group:  property
# Business Name:  Barrel Category:  American (New) Rating:  4.5 Block:  600 - 669 block of pennsylvania avenue se Offense:  theft/other Offense Group:  property
# Business Name:  Barrel Category:  American (New) Rating:  4.5 Block:  600 - 669 block of pennsylvania avenue se Offense:  theft/other Offense Group:  property
# Business Name:  Barrel Category:  American (New) Rating:  4.5 Block:  600 - 669 block of pennsylvania avenue se Offense:  theft/other Offense Group:  property
# Business Name:  Barrel Category:  American (New) Rating:  4.5 Block:  600 - 669 block of pennsylvania avenue se Offense:  theft/other Offense Group:  property
# Business Name:  Barrel Category:  American (New) Rating:  4.5 Block:  600 - 669 block of pennsylvania avenue se Offense:  theft/other Offense Group:  property
# Business Name:  Barrel Category:  American (New) Rating:  4.5 Block:  600 - 669 block of pennsylvania avenue se Offense:  theft/other Offense Group:  property
# Business Name:  Barrel Category:  American (New) Rating:  4.5 Block:  600 - 669 block of pennsylvania avenue se Offense:  theft/other Offense Group:  property
# Business Name:  Barrel Category:  American (New) Rating:  4.5 Block:  600 - 669 block of pennsylvania avenue se Offense:  theft/other Offense Group:  property
# Business Name:  Barrel Category:  American (New) Rating:  4.5 Block:  600 - 669 block of pennsylvania avenue se Offense:  theft/other Offense Group:  property
# Business Name:  Barrel Category:  American (New) Rating:  4.5 Block:  600 - 669 block of pennsylvania avenue se Offense:  theft/other Offense Group:  property
# Business Name:  Barrel Category:  American (New) Rating:  4.5 Block:  600 - 669 block of pennsylvania avenue se Offense:  theft/other Offense Group:  property
# Business Name:  Barrel Category:  American (New) Rating:  4.5 Block:  600 - 669 block of pennsylvania avenue se Offense:  theft/other Offense Group:  property
# Business Name:  Barrel Category:  American (New) Rating:  4.5 Block:  600 - 669 block of pennsylvania avenue se Offense:  theft/other Offense Group:  property
# Business Name:  Barrel Category:  American (New) Rating:  4.5 Block:  600 - 669 block of pennsylvania avenue se Offense:  theft/other Offense Group:  property
# Business Name:  Barrel Category:  American (New) Rating:  4.5 Block:  600 - 669 block of pennsylvania avenue se Offense:  theft/other Offense Group:  property
# Business Name:  Barrel Category:  American (New) Rating:  4.5 Block:  600 - 669 block of pennsylvania avenue se Offense:  theft/other Offense Group:  property
# Business Name:  Barrel Category:  American (New) Rating:  4.5 Block:  600 - 669 block of pennsylvania avenue se Offense:  theft/other Offense Group:  property
# Business Name:  Barrel Category:  American (New) Rating:  4.5 Block:  600 - 669 block of pennsylvania avenue se Offense:  theft/other Offense Group:  property
# Business Name:  Barrel Category:  American (New) Rating:  4.5 Block:  600 - 669 block of pennsylvania avenue se Offense:  theft/other Offense Group:  property
# Business Name:  Barrel Category:  American (New) Rating:  4.5 Block:  600 - 669 block of pennsylvania avenue se Offense:  theft/other Offense Group:  property
# Business Name:  Barrel Category:  American (New) Rating:  4.5 Block:  600 - 669 block of pennsylvania avenue se Offense:  theft/other Offense Group:  property
# Business Name:  Barrel Category:  American (New) Rating:  4.5 Block:  600 - 669 block of pennsylvania avenue se Offense:  theft/other Offense Group:  property
# Business Name:  Barrel Category:  American (New) Rating:  4.5 Block:  600 - 669 block of pennsylvania avenue se Offense:  theft/other Offense Group:  property
# Business Name:  Barrel Category:  American (New) Rating:  4.5 Block:  600 - 669 block of pennsylvania avenue se Offense:  theft/other Offense Group:  property
# Business Name:  Barrel Category:  American (New) Rating:  4.5 Block:  600 - 669 block of pennsylvania avenue se Offense:  theft/other Offense Group:  property
# Business Name:  Barrel Category:  American (New) Rating:  4.5 Block:  600 - 669 block of pennsylvania avenue se Offense:  theft/other Offense Group:  property
# Business Name:  Barrel Category:  American (New) Rating:  4.5 Block:  600 - 669 block of pennsylvania avenue se Offense:  theft/other Offense Group:  property
# Business Name:  Barrel Category:  American (New) Rating:  4.5 Block:  600 - 669 block of pennsylvania avenue se Offense:  theft/other Offense Group:  property
# Business Name:  Barrel Category:  American (New) Rating:  4.5 Block:  600 - 669 block of pennsylvania avenue se Offense:  theft/other Offense Group:  property
# Business Name:  Barrel Category:  American (New) Rating:  4.5 Block:  600 - 669 block of pennsylvania avenue se Offense:  theft/other Offense Group:  property
# Business Name:  Barrel Category:  American (New) Rating:  4.5 Block:  600 - 669 block of pennsylvania avenue se Offense:  theft/other Offense Group:  property
# Business Name:  Barrel Category:  American (New) Rating:  4.5 Block:  600 - 669 block of pennsylvania avenue se Offense:  theft/other Offense Group:  property
# Business Name:  Barrel Category:  American (New) Rating:  4.5 Block:  600 - 669 block of pennsylvania avenue se Offense:  theft/other Offense Group:  property
# Business Name:  Barrel Category:  American (New) Rating:  4.5 Block:  600 - 669 block of pennsylvania avenue se Offense:  theft/other Offense Group:  property
# Business Name:  Barrel Category:  American (New) Rating:  4.5 Block:  600 - 669 block of pennsylvania avenue se Offense:  theft/other Offense Group:  property
# Business Name:  Barrel Category:  American (New) Rating:  4.5 Block:  600 - 669 block of pennsylvania avenue se Offense:  theft/other Offense Group:  property
# Business Name:  Barrel Category:  American (New) Rating:  4.5 Block:  600 - 669 block of pennsylvania avenue se Offense:  theft/other Offense Group:  property
# Business Name:  Barrel Category:  American (New) Rating:  4.5 Block:  600 - 669 block of pennsylvania avenue se Offense:  theft/other Offense Group:  property
# Business Name:  Barrel Category:  American (New) Rating:  4.5 Block:  600 - 669 block of pennsylvania avenue se Offense:  theft/other Offense Group:  property
# Business Name:  Barrel Category:  American (New) Rating:  4.5 Block:  600 - 669 block of pennsylvania avenue se Offense:  theft/other Offense Group:  property
# Business Name:  Barrel Category:  American (New) Rating:  4.5 Block:  600 - 669 block of pennsylvania avenue se Offense:  theft/other Offense Group:  property
# Business Name:  Barrel Category:  American (New) Rating:  4.5 Block:  600 - 669 block of pennsylvania avenue se Offense:  theft/other Offense Group:  property
# Business Name:  Barrel Category:  American (New) Rating:  4.5 Block:  600 - 669 block of pennsylvania avenue se Offense:  theft/other Offense Group:  property
# Business Name:  Barrel Category:  American (New) Rating:  4.5 Block:  600 - 669 block of pennsylvania avenue se Offense:  theft/other Offense Group:  property
# Business Name:  Barrel Category:  American (New) Rating:  4.5 Block:  600 - 669 block of pennsylvania avenue se Offense:  theft/other Offense Group:  property
# Business Name:  Barrel Category:  American (New) Rating:  4.5 Block:  600 - 669 block of pennsylvania avenue se Offense:  theft/other Offense Group:  property
# Business Name:  Barrel Category:  American (New) Rating:  4.5 Block:  600 - 669 block of pennsylvania avenue se Offense:  theft/other Offense Group:  property
# Business Name:  Barrel Category:  American (New) Rating:  4.5 Block:  600 - 669 block of pennsylvania avenue se Offense:  theft/other Offense Group:  property
# Business Name:  Barrel Category:  American (New) Rating:  4.5 Block:  600 - 669 block of pennsylvania avenue se Offense:  theft/other Offense Group:  property
# Business Name:  Barrel Category:  American (New) Rating:  4.5 Block:  600 - 669 block of pennsylvania avenue se Offense:  theft/other Offense Group:  property
# Business Name:  Barrel Category:  American (New) Rating:  4.5 Block:  600 - 669 block of pennsylvania avenue se Offense:  theft/other Offense Group:  property
# Business Name:  Barrel Category:  American (New) Rating:  4.5 Block:  600 - 669 block of pennsylvania avenue se Offense:  theft/other Offense Group:  property
# Business Name:  Barrel Category:  American (New) Rating:  4.5 Block:  600 - 669 block of pennsylvania avenue se Offense:  theft/other Offense Group:  property
# Business Name:  Barrel Category:  American (New) Rating:  4.5 Block:  600 - 669 block of pennsylvania avenue se Offense:  theft/other Offense Group:  property
# Business Name:  Barrel Category:  American (New) Rating:  4.5 Block:  600 - 669 block of pennsylvania avenue se Offense:  theft/other Offense Group:  property
# Business Name:  Barrel Category:  American (New) Rating:  4.5 Block:  600 - 669 block of pennsylvania avenue se Offense:  theft/other Offense Group:  property
# Business Name:  Barrel Category:  American (New) Rating:  4.5 Block:  600 - 669 block of pennsylvania avenue se Offense:  theft/other Offense Group:  property
# Business Name:  Barrel Category:  American (New) Rating:  4.5 Block:  600 - 669 block of pennsylvania avenue se Offense:  theft/other Offense Group:  property
# Business Name:  Barrel Category:  American (New) Rating:  4.5 Block:  600 - 669 block of pennsylvania avenue se Offense:  theft/other Offense Group:  property
# Business Name:  Barrel Category:  American (New) Rating:  4.5 Block:  600 - 669 block of pennsylvania avenue se Offense:  theft/other Offense Group:  property
# Business Name:  Barrel Category:  American (New) Rating:  4.5 Block:  600 - 669 block of pennsylvania avenue se Offense:  theft/other Offense Group:  property
# Business Name:  Barrel Category:  American (New) Rating:  4.5 Block:  600 - 669 block of pennsylvania avenue se Offense:  theft/other Offense Group:  property
# Business Name:  Barrel Category:  American (New) Rating:  4.5 Block:  600 - 669 block of pennsylvania avenue se Offense:  theft/other Offense Group:  property
# Business Name:  Barrel Category:  American (New) Rating:  4.5 Block:  600 - 669 block of pennsylvania avenue se Offense:  theft/other Offense Group:  property
# Business Name:  Barrel Category:  American (New) Rating:  4.5 Block:  600 - 669 block of pennsylvania avenue se Offense:  theft/other Offense Group:  property
# Business Name:  Barrel Category:  American (New) Rating:  4.5 Block:  600 - 669 block of pennsylvania avenue se Offense:  theft/other Offense Group:  property
# Business Name:  Barrel Category:  American (New) Rating:  4.5 Block:  600 - 669 block of pennsylvania avenue se Offense:  theft/other Offense Group:  property
# Business Name:  Barrel Category:  American (New) Rating:  4.5 Block:  600 - 669 block of pennsylvania avenue se Offense:  theft/other Offense Group:  property
# Business Name:  Barrel Category:  American (New) Rating:  4.5 Block:  600 - 669 block of pennsylvania avenue se Offense:  theft/other Offense Group:  property
# Business Name:  Barrel Category:  American (New) Rating:  4.5 Block:  600 - 669 block of pennsylvania avenue se Offense:  theft/other Offense Group:  property
# Business Name:  Barrel Category:  American (New) Rating:  4.5 Block:  600 - 669 block of pennsylvania avenue se Offense:  theft/other Offense Group:  property
# Business Name:  Barrel Category:  American (New) Rating:  4.5 Block:  600 - 669 block of pennsylvania avenue se Offense:  theft/other Offense Group:  property
# Business Name:  Barrel Category:  American (New) Rating:  4.5 Block:  600 - 669 block of pennsylvania avenue se Offense:  theft/other Offense Group:  property
# Business Name:  Barrel Category:  American (New) Rating:  4.5 Block:  600 - 669 block of pennsylvania avenue se Offense:  theft/other Offense Group:  property
# Business Name:  Barrel Category:  American (New) Rating:  4.5 Block:  600 - 669 block of pennsylvania avenue se Offense:  theft/other Offense Group:  property
# Business Name:  Barrel Category:  American (New) Rating:  4.5 Block:  600 - 669 block of pennsylvania avenue se Offense:  theft/other Offense Group:  property
# Business Name:  Barrel Category:  American (New) Rating:  4.5 Block:  600 - 669 block of pennsylvania avenue se Offense:  theft/other Offense Group:  property
# Business Name:  Barrel Category:  American (New) Rating:  4.5 Block:  600 - 669 block of pennsylvania avenue se Offense:  theft/other Offense Group:  property
# Business Name:  Barrel Category:  American (New) Rating:  4.5 Block:  600 - 669 block of pennsylvania avenue se Offense:  theft/other Offense Group:  property
# Business Name:  Barrel Category:  American (New) Rating:  4.5 Block:  600 - 669 block of pennsylvania avenue se Offense:  theft/other Offense Group:  property
# Business Name:  Barrel Category:  American (New) Rating:  4.5 Block:  600 - 669 block of pennsylvania avenue se Offense:  theft/other Offense Group:  property
# Business Name:  Barrel Category:  American (New) Rating:  4.5 Block:  600 - 669 block of pennsylvania avenue se Offense:  theft/other Offense Group:  property
# Business Name:  Barrel Category:  American (New) Rating:  4.5 Block:  600 - 669 block of pennsylvania avenue se Offense:  theft/other Offense Group:  property
# Business Name:  Barrel Category:  American (New) Rating:  4.5 Block:  600 - 669 block of pennsylvania avenue se Offense:  theft/other Offense Group:  property
# Business Name:  Barrel Category:  American (New) Rating:  4.5 Block:  600 - 669 block of pennsylvania avenue se Offense:  theft/other Offense Group:  property
# Business Name:  Barrel Category:  American (New) Rating:  4.5 Block:  600 - 669 block of pennsylvania avenue se Offense:  theft/other Offense Group:  property
# Business Name:  Barrel Category:  American (New) Rating:  4.5 Block:  600 - 669 block of pennsylvania avenue se Offense:  theft/other Offense Group:  property
# Business Name:  Barrel Category:  American (New) Rating:  4.5 Block:  600 - 669 block of pennsylvania avenue se Offense:  theft/other Offense Group:  property
# Business Name:  Barrel Category:  American (New) Rating:  4.5 Block:  600 - 669 block of pennsylvania avenue se Offense:  theft/other Offense Group:  property
# Business Name:  Barrel Category:  American (New) Rating:  4.5 Block:  600 - 669 block of pennsylvania avenue se Offense:  theft/other Offense Group:  property
# Business Name:  Barrel Category:  American (New) Rating:  4.5 Block:  600 - 669 block of pennsylvania avenue se Offense:  theft/other Offense Group:  property
# Business Name:  Barrel Category:  American (New) Rating:  4.5 Block:  600 - 669 block of pennsylvania avenue se Offense:  theft/other Offense Group:  property
# Business Name:  Barrel Category:  American (New) Rating:  4.5 Block:  600 - 669 block of pennsylvania avenue se Offense:  theft/other Offense Group:  property
# Business Name:  Barrel Category:  American (New) Rating:  4.5 Block:  600 - 669 block of pennsylvania avenue se Offense:  theft/other Offense Group:  property
# Business Name:  Barrel Category:  American (New) Rating:  4.5 Block:  600 - 669 block of pennsylvania avenue se Offense:  theft/other Offense Group:  property
# Business Name:  Barrel Category:  American (New) Rating:  4.5 Block:  600 - 669 block of pennsylvania avenue se Offense:  theft/other Offense Group:  property
# Business Name:  Barrel Category:  American (New) Rating:  4.5 Block:  600 - 669 block of pennsylvania avenue se Offense:  theft/other Offense Group:  property
# Business Name:  Barrel Category:  American (New) Rating:  4.5 Block:  600 - 669 block of pennsylvania avenue se Offense:  theft/other Offense Group:  property
# Business Name:  Barrel Category:  American (New) Rating:  4.5 Block:  600 - 669 block of pennsylvania avenue se Offense:  theft/other Offense Group:  property
# Business Name:  Barrel Category:  American (New) Rating:  4.5 Block:  600 - 669 block of pennsylvania avenue se Offense:  theft/other Offense Group:  property
# Business Name:  Barrel Category:  American (New) Rating:  4.5 Block:  600 - 669 block of pennsylvania avenue se Offense:  theft/other Offense Group:  property
# Business Name:  Barrel Category:  American (New) Rating:  4.5 Block:  600 - 669 block of pennsylvania avenue se Offense:  theft/other Offense Group:  property
# Business Name:  Barrel Category:  American (New) Rating:  4.5 Block:  600 - 669 block of pennsylvania avenue se Offense:  theft/other Offense Group:  property
# Business Name:  Barrel Category:  American (New) Rating:  4.5 Block:  600 - 669 block of pennsylvania avenue se Offense:  theft/other Offense Group:  property
# Business Name:  Barrel Category:  American (New) Rating:  4.5 Block:  600 - 669 block of pennsylvania avenue se Offense:  theft/other Offense Group:  property
# Business Name:  Barrel Category:  American (New) Rating:  4.5 Block:  600 - 669 block of pennsylvania avenue se Offense:  theft/other Offense Group:  property
# Business Name:  Barrel Category:  American (New) Rating:  4.5 Block:  600 - 669 block of pennsylvania avenue se Offense:  theft/other Offense Group:  property
# Business Name:  Barrel Category:  American (New) Rating:  4.5 Block:  600 - 669 block of pennsylvania avenue se Offense:  theft/other Offense Group:  property
# Business Name:  Barrel Category:  American (New) Rating:  4.5 Block:  600 - 669 block of pennsylvania avenue se Offense:  theft/other Offense Group:  property
# Business Name:  Barrel Category:  American (New) Rating:  4.5 Block:  600 - 669 block of pennsylvania avenue se Offense:  theft/other Offense Group:  property
# Business Name:  Barrel Category:  American (New) Rating:  4.5 Block:  600 - 669 block of pennsylvania avenue se Offense:  theft/other Offense Group:  property
# Business Name:  Barrel Category:  American (New) Rating:  4.5 Block:  600 - 669 block of pennsylvania avenue se Offense:  theft/other Offense Group:  property
# Business Name:  Barrel Category:  American (New) Rating:  4.5 Block:  600 - 669 block of pennsylvania avenue se Offense:  theft/other Offense Group:  property
# Business Name:  Barrel Category:  American (New) Rating:  4.5 Block:  600 - 669 block of pennsylvania avenue se Offense:  theft/other Offense Group:  property
# Business Name:  Barrel Category:  American (New) Rating:  4.5 Block:  600 - 669 block of pennsylvania avenue se Offense:  theft/other Offense Group:  property
# Business Name:  Barrel Category:  American (New) Rating:  4.5 Block:  600 - 669 block of pennsylvania avenue se Offense:  theft/other Offense Group:  property
# Business Name:  Barrel Category:  American (New) Rating:  4.5 Block:  600 - 669 block of pennsylvania avenue se Offense:  theft/other Offense Group:  property
# Business Name:  Barrel Category:  American (New) Rating:  4.5 Block:  600 - 669 block of pennsylvania avenue se Offense:  theft/other Offense Group:  property
# Business Name:  Barrel Category:  American (New) Rating:  4.5 Block:  600 - 669 block of pennsylvania avenue se Offense:  theft/other Offense Group:  property
# Business Name:  Barrel Category:  American (New) Rating:  4.5 Block:  600 - 669 block of pennsylvania avenue se Offense:  theft/other Offense Group:  property
# Business Name:  Barrel Category:  American (New) Rating:  4.5 Block:  600 - 669 block of pennsylvania avenue se Offense:  theft/other Offense Group:  property
# Business Name:  Barrel Category:  American (New) Rating:  4.5 Block:  600 - 669 block of pennsylvania avenue se Offense:  theft/other Offense Group:  property
# Business Name:  Barrel Category:  American (New) Rating:  4.5 Block:  600 - 669 block of pennsylvania avenue se Offense:  theft/other Offense Group:  property
# Business Name:  Barrel Category:  American (New) Rating:  4.5 Block:  600 - 669 block of pennsylvania avenue se Offense:  theft/other Offense Group:  property
# Business Name:  Barrel Category:  American (New) Rating:  4.5 Block:  600 - 669 block of pennsylvania avenue se Offense:  theft/other Offense Group:  property
# Business Name:  Barrel Category:  American (New) Rating:  4.5 Block:  600 - 669 block of pennsylvania avenue se Offense:  theft/other Offense Group:  property
# Business Name:  Barrel Category:  American (New) Rating:  4.5 Block:  600 - 669 block of pennsylvania avenue se Offense:  theft/other Offense Group:  property
# Business Name:  Barrel Category:  American (New) Rating:  4.5 Block:  600 - 669 block of pennsylvania avenue se Offense:  theft/other Offense Group:  property
# Business Name:  Barrel Category:  American (New) Rating:  4.5 Block:  600 - 669 block of pennsylvania avenue se Offense:  theft/other Offense Group:  property
# Business Name:  Barrel Category:  American (New) Rating:  4.5 Block:  600 - 669 block of pennsylvania avenue se Offense:  theft/other Offense Group:  property
# Business Name:  Barrel Category:  American (New) Rating:  4.5 Block:  600 - 669 block of pennsylvania avenue se Offense:  theft/other Offense Group:  property
# Business Name:  Barrel Category:  American (New) Rating:  4.5 Block:  600 - 669 block of pennsylvania avenue se Offense:  theft/other Offense Group:  property
# Business Name:  Barrel Category:  American (New) Rating:  4.5 Block:  600 - 669 block of pennsylvania avenue se Offense:  theft/other Offense Group:  property
# Business Name:  Barrel Category:  American (New) Rating:  4.5 Block:  600 - 669 block of pennsylvania avenue se Offense:  theft/other Offense Group:  property
# Business Name:  Barrel Category:  American (New) Rating:  4.5 Block:  600 - 669 block of pennsylvania avenue se Offense:  theft/other Offense Group:  property
# Business Name:  Barrel Category:  American (New) Rating:  4.5 Block:  600 - 669 block of pennsylvania avenue se Offense:  theft/other Offense Group:  property
# Business Name:  Barrel Category:  American (New) Rating:  4.5 Block:  600 - 669 block of pennsylvania avenue se Offense:  theft/other Offense Group:  property
# Business Name:  Barrel Category:  American (New) Rating:  4.5 Block:  600 - 669 block of pennsylvania avenue se Offense:  theft/other Offense Group:  property
# Business Name:  Barrel Category:  American (New) Rating:  4.5 Block:  600 - 669 block of pennsylvania avenue se Offense:  theft/other Offense Group:  property
# Business Name:  Barrel Category:  American (New) Rating:  4.5 Block:  600 - 669 block of pennsylvania avenue se Offense:  theft/other Offense Group:  property
# Business Name:  Barrel Category:  American (New) Rating:  4.5 Block:  600 - 669 block of pennsylvania avenue se Offense:  theft/other Offense Group:  property
# Business Name:  Barrel Category:  American (New) Rating:  4.5 Block:  600 - 669 block of pennsylvania avenue se Offense:  theft/other Offense Group:  property
# Business Name:  Barrel Category:  American (New) Rating:  4.5 Block:  600 - 669 block of pennsylvania avenue se Offense:  theft/other Offense Group:  property
# Business Name:  Barrel Category:  American (New) Rating:  4.5 Block:  600 - 669 block of pennsylvania avenue se Offense:  theft/other Offense Group:  property
# Business Name:  Barrel Category:  American (New) Rating:  4.5 Block:  600 - 669 block of pennsylvania avenue se Offense:  theft/other Offense Group:  property
# Business Name:  Barrel Category:  American (New) Rating:  4.5 Block:  600 - 669 block of pennsylvania avenue se Offense:  theft/other Offense Group:  property
# Business Name:  Barrel Category:  American (New) Rating:  4.5 Block:  600 - 669 block of pennsylvania avenue se Offense:  theft/other Offense Group:  property
# Business Name:  Barrel Category:  American (New) Rating:  4.5 Block:  600 - 669 block of pennsylvania avenue se Offense:  theft/other Offense Group:  property
# Business Name:  Farmbird Category:  Chicken Shop Rating:  5 Block:  600 - 699 block of h street ne Offense:  burglary Offense Group:  property
# Business Name:  Farmbird Category:  Chicken Shop Rating:  5 Block:  600 - 699 block of h street ne Offense:  motor vehicle theft Offense Group:  property
# Business Name:  Farmbird Category:  Chicken Shop Rating:  5 Block:  600 - 699 block of h street ne Offense:  robbery Offense Group:  violent
# Business Name:  Farmbird Category:  Chicken Shop Rating:  5 Block:  600 - 699 block of h street ne Offense:  theft f/auto Offense Group:  property
# Business Name:  Farmbird Category:  Chicken Shop Rating:  5 Block:  600 - 699 block of h street ne Offense:  theft f/auto Offense Group:  property
# Business Name:  Farmbird Category:  Chicken Shop Rating:  5 Block:  600 - 699 block of h street ne Offense:  theft f/auto Offense Group:  property
# Business Name:  Farmbird Category:  Chicken Shop Rating:  5 Block:  600 - 699 block of h street ne Offense:  theft f/auto Offense Group:  property
# Business Name:  Farmbird Category:  Chicken Shop Rating:  5 Block:  600 - 699 block of h street ne Offense:  theft f/auto Offense Group:  property
# Business Name:  Farmbird Category:  Chicken Shop Rating:  5 Block:  600 - 699 block of h street ne Offense:  theft f/auto Offense Group:  property
# Business Name:  Farmbird Category:  Chicken Shop Rating:  5 Block:  600 - 699 block of h street ne Offense:  theft f/auto Offense Group:  property
# Business Name:  Farmbird Category:  Chicken Shop Rating:  5 Block:  600 - 699 block of h street ne Offense:  theft f/auto Offense Group:  property
# Business Name:  Farmbird Category:  Chicken Shop Rating:  5 Block:  600 - 699 block of h street ne Offense:  theft f/auto Offense Group:  property
# Business Name:  Farmbird Category:  Chicken Shop Rating:  5 Block:  600 - 699 block of h street ne Offense:  theft f/auto Offense Group:  property
# Business Name:  Farmbird Category:  Chicken Shop Rating:  5 Block:  600 - 699 block of h street ne Offense:  theft f/auto Offense Group:  property
# Business Name:  Farmbird Category:  Chicken Shop Rating:  5 Block:  600 - 699 block of h street ne Offense:  theft f/auto Offense Group:  property
# Business Name:  Farmbird Category:  Chicken Shop Rating:  5 Block:  600 - 699 block of h street ne Offense:  theft f/auto Offense Group:  property
# Business Name:  Farmbird Category:  Chicken Shop Rating:  5 Block:  600 - 699 block of h street ne Offense:  theft/other Offense Group:  property
# Business Name:  Farmbird Category:  Chicken Shop Rating:  5 Block:  600 - 699 block of h street ne Offense:  theft/other Offense Group:  property
# Business Name:  Farmbird Category:  Chicken Shop Rating:  5 Block:  600 - 699 block of h street ne Offense:  theft/other Offense Group:  property
# Business Name:  Farmbird Category:  Chicken Shop Rating:  5 Block:  600 - 699 block of h street ne Offense:  theft/other Offense Group:  property
# Business Name:  Farmbird Category:  Chicken Shop Rating:  5 Block:  600 - 699 block of h street ne Offense:  theft/other Offense Group:  property
# Business Name:  Farmbird Category:  Chicken Shop Rating:  5 Block:  600 - 699 block of h street ne Offense:  theft/other Offense Group:  property
# Business Name:  Farmbird Category:  Chicken Shop Rating:  5 Block:  600 - 699 block of h street ne Offense:  theft/other Offense Group:  property
# Business Name:  Farmbird Category:  Chicken Shop Rating:  5 Block:  600 - 699 block of h street ne Offense:  theft/other Offense Group:  property
# Business Name:  Farmbird Category:  Chicken Shop Rating:  5 Block:  600 - 699 block of h street ne Offense:  theft/other Offense Group:  property
# Business Name:  Farmbird Category:  Chicken Shop Rating:  5 Block:  600 - 699 block of h street ne Offense:  theft/other Offense Group:  property
# Business Name:  Farmbird Category:  Chicken Shop Rating:  5 Block:  600 - 699 block of h street ne Offense:  theft/other Offense Group:  property
# Business Name:  Farmbird Category:  Chicken Shop Rating:  5 Block:  600 - 699 block of h street ne Offense:  theft/other Offense Group:  property
# Business Name:  Farmbird Category:  Chicken Shop Rating:  5 Block:  600 - 699 block of h street ne Offense:  theft/other Offense Group:  property
# Business Name:  Farmbird Category:  Chicken Shop Rating:  5 Block:  600 - 699 block of h street ne Offense:  theft/other Offense Group:  property
# Business Name:  Farmbird Category:  Chicken Shop Rating:  5 Block:  600 - 699 block of h street ne Offense:  theft/other Offense Group:  property
# Business Name:  Farmbird Category:  Chicken Shop Rating:  5 Block:  600 - 699 block of h street ne Offense:  theft/other Offense Group:  property
# Business Name:  Farmbird Category:  Chicken Shop Rating:  5 Block:  600 - 699 block of h street ne Offense:  theft/other Offense Group:  property
# Business Name:  Farmbird Category:  Chicken Shop Rating:  5 Block:  600 - 699 block of h street ne Offense:  theft/other Offense Group:  property
# Business Name:  Farmbird Category:  Chicken Shop Rating:  5 Block:  600 - 699 block of h street ne Offense:  theft/other Offense Group:  property
# Business Name:  Farmbird Category:  Chicken Shop Rating:  5 Block:  600 - 699 block of h street ne Offense:  theft/other Offense Group:  property
# Business Name:  Farmbird Category:  Chicken Shop Rating:  5 Block:  600 - 699 block of h street ne Offense:  theft/other Offense Group:  property
# Business Name:  Farmbird Category:  Chicken Shop Rating:  5 Block:  600 - 699 block of h street ne Offense:  theft/other Offense Group:  property
# Business Name:  Farmbird Category:  Chicken Shop Rating:  5 Block:  600 - 699 block of h street ne Offense:  theft/other Offense Group:  property
# Business Name:  Farmbird Category:  Chicken Shop Rating:  5 Block:  600 - 699 block of h street ne Offense:  theft/other Offense Group:  property
# Business Name:  Farmbird Category:  Chicken Shop Rating:  5 Block:  600 - 699 block of h street ne Offense:  theft/other Offense Group:  property
# Business Name:  Farmbird Category:  Chicken Shop Rating:  5 Block:  600 - 699 block of h street ne Offense:  theft/other Offense Group:  property
# Business Name:  Farmbird Category:  Chicken Shop Rating:  5 Block:  600 - 699 block of h street ne Offense:  theft/other Offense Group:  property
# Business Name:  Farmbird Category:  Chicken Shop Rating:  5 Block:  600 - 699 block of h street ne Offense:  theft/other Offense Group:  property
# Business Name:  Farmbird Category:  Chicken Shop Rating:  5 Block:  600 - 699 block of h street ne Offense:  theft/other Offense Group:  property
# Business Name:  Farmbird Category:  Chicken Shop Rating:  5 Block:  600 - 699 block of h street ne Offense:  theft/other Offense Group:  property
# Business Name:  Farmbird Category:  Chicken Shop Rating:  5 Block:  600 - 699 block of h street ne Offense:  theft/other Offense Group:  property
# Business Name:  Farmbird Category:  Chicken Shop Rating:  5 Block:  600 - 699 block of h street ne Offense:  theft/other Offense Group:  property
# Business Name:  Farmbird Category:  Chicken Shop Rating:  5 Block:  600 - 699 block of h street ne Offense:  theft/other Offense Group:  property
# Business Name:  Farmbird Category:  Chicken Shop Rating:  5 Block:  600 - 699 block of h street ne Offense:  theft/other Offense Group:  property
# Business Name:  Farmbird Category:  Chicken Shop Rating:  5 Block:  600 - 699 block of h street ne Offense:  theft/other Offense Group:  property
# Business Name:  Farmbird Category:  Chicken Shop Rating:  5 Block:  600 - 699 block of h street ne Offense:  theft/other Offense Group:  property
# Business Name:  Farmbird Category:  Chicken Shop Rating:  5 Block:  600 - 699 block of h street ne Offense:  theft/other Offense Group:  property
# Business Name:  Farmbird Category:  Chicken Shop Rating:  5 Block:  600 - 699 block of h street ne Offense:  theft/other Offense Group:  property
# Business Name:  Farmbird Category:  Chicken Shop Rating:  5 Block:  600 - 699 block of h street ne Offense:  theft/other Offense Group:  property
# Business Name:  Farmbird Category:  Chicken Shop Rating:  5 Block:  600 - 699 block of h street ne Offense:  theft/other Offense Group:  property
# Business Name:  Farmbird Category:  Chicken Shop Rating:  5 Block:  600 - 699 block of h street ne Offense:  theft/other Offense Group:  property
# Business Name:  Farmbird Category:  Chicken Shop Rating:  5 Block:  600 - 699 block of h street ne Offense:  theft/other Offense Group:  property
# Business Name:  Farmbird Category:  Chicken Shop Rating:  5 Block:  600 - 699 block of h street ne Offense:  theft/other Offense Group:  property
# Business Name:  Farmbird Category:  Chicken Shop Rating:  5 Block:  600 - 699 block of h street ne Offense:  theft/other Offense Group:  property
# Business Name:  Farmbird Category:  Chicken Shop Rating:  5 Block:  600 - 699 block of h street ne Offense:  theft/other Offense Group:  property
# Business Name:  Farmbird Category:  Chicken Shop Rating:  5 Block:  600 - 699 block of h street ne Offense:  theft/other Offense Group:  property
# Business Name:  Farmbird Category:  Chicken Shop Rating:  5 Block:  600 - 699 block of h street ne Offense:  theft/other Offense Group:  property
# Business Name:  Farmbird Category:  Chicken Shop Rating:  5 Block:  600 - 699 block of h street ne Offense:  theft/other Offense Group:  property
# Business Name:  Farmbird Category:  Chicken Shop Rating:  5 Block:  600 - 699 block of h street ne Offense:  theft/other Offense Group:  property
# Business Name:  Farmbird Category:  Chicken Shop Rating:  5 Block:  600 - 699 block of h street ne Offense:  theft/other Offense Group:  property
# Business Name:  Farmbird Category:  Chicken Shop Rating:  5 Block:  600 - 699 block of h street ne Offense:  theft/other Offense Group:  property
# Business Name:  Farmbird Category:  Chicken Shop Rating:  5 Block:  600 - 699 block of h street ne Offense:  theft/other Offense Group:  property
# Business Name:  Farmbird Category:  Chicken Shop Rating:  5 Block:  600 - 699 block of h street ne Offense:  theft/other Offense Group:  property
# Business Name:  Farmbird Category:  Chicken Shop Rating:  5 Block:  600 - 699 block of h street ne Offense:  theft/other Offense Group:  property
# Business Name:  Farmbird Category:  Chicken Shop Rating:  5 Block:  600 - 699 block of h street ne Offense:  theft/other Offense Group:  property
# Business Name:  Farmbird Category:  Chicken Shop Rating:  5 Block:  600 - 699 block of h street ne Offense:  theft/other Offense Group:  property
# Business Name:  Farmbird Category:  Chicken Shop Rating:  5 Block:  600 - 699 block of h street ne Offense:  theft/other Offense Group:  property
# Business Name:  Farmbird Category:  Chicken Shop Rating:  5 Block:  600 - 699 block of h street ne Offense:  theft/other Offense Group:  property
# Business Name:  Farmbird Category:  Chicken Shop Rating:  5 Block:  600 - 699 block of h street ne Offense:  theft/other Offense Group:  property
# Business Name:  Farmbird Category:  Chicken Shop Rating:  5 Block:  600 - 699 block of h street ne Offense:  theft/other Offense Group:  property
# Business Name:  Farmbird Category:  Chicken Shop Rating:  5 Block:  600 - 699 block of h street ne Offense:  theft/other Offense Group:  property
# Business Name:  Farmbird Category:  Chicken Shop Rating:  5 Block:  600 - 699 block of h street ne Offense:  theft/other Offense Group:  property
# Business Name:  Farmbird Category:  Chicken Shop Rating:  5 Block:  600 - 699 block of h street ne Offense:  theft/other Offense Group:  property
# Business Name:  Farmbird Category:  Chicken Shop Rating:  5 Block:  600 - 699 block of h street ne Offense:  theft/other Offense Group:  property
# Business Name:  Farmbird Category:  Chicken Shop Rating:  5 Block:  600 - 699 block of h street ne Offense:  theft/other Offense Group:  property
# Business Name:  Farmbird Category:  Chicken Shop Rating:  5 Block:  600 - 699 block of h street ne Offense:  theft/other Offense Group:  property
# Business Name:  Farmbird Category:  Chicken Shop Rating:  5 Block:  600 - 699 block of h street ne Offense:  theft/other Offense Group:  property
# Business Name:  Farmbird Category:  Chicken Shop Rating:  5 Block:  600 - 699 block of h street ne Offense:  theft/other Offense Group:  property
# Business Name:  Farmbird Category:  Chicken Shop Rating:  5 Block:  600 - 699 block of h street ne Offense:  theft/other Offense Group:  property
# Business Name:  Farmbird Category:  Chicken Shop Rating:  5 Block:  600 - 699 block of h street ne Offense:  theft/other Offense Group:  property
# Business Name:  Farmbird Category:  Chicken Shop Rating:  5 Block:  600 - 699 block of h street ne Offense:  theft/other Offense Group:  property
# Business Name:  Farmbird Category:  Chicken Shop Rating:  5 Block:  600 - 699 block of h street ne Offense:  theft/other Offense Group:  property
# Business Name:  Farmbird Category:  Chicken Shop Rating:  5 Block:  600 - 699 block of h street ne Offense:  theft/other Offense Group:  property
# Business Name:  Farmbird Category:  Chicken Shop Rating:  5 Block:  600 - 699 block of h street ne Offense:  theft/other Offense Group:  property
# Business Name:  Farmbird Category:  Chicken Shop Rating:  5 Block:  600 - 699 block of h street ne Offense:  theft/other Offense Group:  property
# Business Name:  Farmbird Category:  Chicken Shop Rating:  5 Block:  600 - 699 block of h street ne Offense:  theft/other Offense Group:  property
# Business Name:  Farmbird Category:  Chicken Shop Rating:  5 Block:  600 - 699 block of h street ne Offense:  theft/other Offense Group:  property
# Business Name:  Farmbird Category:  Chicken Shop Rating:  5 Block:  600 - 699 block of h street ne Offense:  theft/other Offense Group:  property
# Business Name:  Farmbird Category:  Chicken Shop Rating:  5 Block:  600 - 699 block of h street ne Offense:  theft/other Offense Group:  property
# Business Name:  Farmbird Category:  Chicken Shop Rating:  5 Block:  600 - 699 block of h street ne Offense:  theft/other Offense Group:  property
# Business Name:  Farmbird Category:  Chicken Shop Rating:  5 Block:  600 - 699 block of h street ne Offense:  theft/other Offense Group:  property
# Business Name:  Farmbird Category:  Chicken Shop Rating:  5 Block:  600 - 699 block of h street ne Offense:  theft/other Offense Group:  property
# Business Name:  Farmbird Category:  Chicken Shop Rating:  5 Block:  600 - 699 block of h street ne Offense:  theft/other Offense Group:  property
# Business Name:  Farmbird Category:  Chicken Shop Rating:  5 Block:  600 - 699 block of h street ne Offense:  theft/other Offense Group:  property
# Business Name:  Farmbird Category:  Chicken Shop Rating:  5 Block:  600 - 699 block of h street ne Offense:  theft/other Offense Group:  property
# Business Name:  Farmbird Category:  Chicken Shop Rating:  5 Block:  600 - 699 block of h street ne Offense:  theft/other Offense Group:  property
# Business Name:  Farmbird Category:  Chicken Shop Rating:  5 Block:  600 - 699 block of h street ne Offense:  theft/other Offense Group:  property
# Business Name:  Farmbird Category:  Chicken Shop Rating:  5 Block:  600 - 699 block of h street ne Offense:  theft/other Offense Group:  property
# Business Name:  Farmbird Category:  Chicken Shop Rating:  5 Block:  600 - 699 block of h street ne Offense:  theft/other Offense Group:  property
# Business Name:  Farmbird Category:  Chicken Shop Rating:  5 Block:  600 - 699 block of h street ne Offense:  theft/other Offense Group:  property
# Business Name:  Farmbird Category:  Chicken Shop Rating:  5 Block:  600 - 699 block of h street ne Offense:  theft/other Offense Group:  property
# Business Name:  Farmbird Category:  Chicken Shop Rating:  5 Block:  600 - 699 block of h street ne Offense:  theft/other Offense Group:  property
# Business Name:  Farmbird Category:  Chicken Shop Rating:  5 Block:  600 - 699 block of h street ne Offense:  theft/other Offense Group:  property
# Business Name:  Farmbird Category:  Chicken Shop Rating:  5 Block:  600 - 699 block of h street ne Offense:  theft/other Offense Group:  property
# Business Name:  Farmbird Category:  Chicken Shop Rating:  5 Block:  600 - 699 block of h street ne Offense:  theft/other Offense Group:  property
# Business Name:  Farmbird Category:  Chicken Shop Rating:  5 Block:  600 - 699 block of h street ne Offense:  theft/other Offense Group:  property
# Business Name:  Farmbird Category:  Chicken Shop Rating:  5 Block:  600 - 699 block of h street ne Offense:  theft/other Offense Group:  property
# Business Name:  Farmbird Category:  Chicken Shop Rating:  5 Block:  600 - 699 block of h street ne Offense:  theft/other Offense Group:  property
# Business Name:  Farmbird Category:  Chicken Shop Rating:  5 Block:  600 - 699 block of h street ne Offense:  theft/other Offense Group:  property
# Business Name:  Farmbird Category:  Chicken Shop Rating:  5 Block:  600 - 699 block of h street ne Offense:  theft/other Offense Group:  property
# Business Name:  Farmbird Category:  Chicken Shop Rating:  5 Block:  600 - 699 block of h street ne Offense:  theft/other Offense Group:  property
# Business Name:  Farmbird Category:  Chicken Shop Rating:  5 Block:  600 - 699 block of h street ne Offense:  theft/other Offense Group:  property
# Business Name:  Farmbird Category:  Chicken Shop Rating:  5 Block:  600 - 699 block of h street ne Offense:  theft/other Offense Group:  property
# Business Name:  Farmbird Category:  Chicken Shop Rating:  5 Block:  600 - 699 block of h street ne Offense:  theft/other Offense Group:  property
# Business Name:  Farmbird Category:  Chicken Shop Rating:  5 Block:  600 - 699 block of h street ne Offense:  theft/other Offense Group:  property
# Business Name:  Farmbird Category:  Chicken Shop Rating:  5 Block:  600 - 699 block of h street ne Offense:  theft/other Offense Group:  property
# Business Name:  Farmbird Category:  Chicken Shop Rating:  5 Block:  600 - 699 block of h street ne Offense:  theft/other Offense Group:  property
# Business Name:  Farmbird Category:  Chicken Shop Rating:  5 Block:  600 - 699 block of h street ne Offense:  theft/other Offense Group:  property
# Business Name:  Farmbird Category:  Chicken Shop Rating:  5 Block:  600 - 699 block of h street ne Offense:  theft/other Offense Group:  property
# Business Name:  Farmbird Category:  Chicken Shop Rating:  5 Block:  600 - 699 block of h street ne Offense:  theft/other Offense Group:  property
# Business Name:  Farmbird Category:  Chicken Shop Rating:  5 Block:  600 - 699 block of h street ne Offense:  theft/other Offense Group:  property
# Business Name:  Farmbird Category:  Chicken Shop Rating:  5 Block:  600 - 699 block of h street ne Offense:  theft/other Offense Group:  property
# Business Name:  Farmbird Category:  Chicken Shop Rating:  5 Block:  600 - 699 block of h street ne Offense:  theft/other Offense Group:  property
# Business Name:  Farmbird Category:  Chicken Shop Rating:  5 Block:  600 - 699 block of h street ne Offense:  theft/other Offense Group:  property
# Business Name:  Farmbird Category:  Chicken Shop Rating:  5 Block:  600 - 699 block of h street ne Offense:  theft/other Offense Group:  property
# Business Name:  Farmbird Category:  Chicken Shop Rating:  5 Block:  600 - 699 block of h street ne Offense:  theft/other Offense Group:  property
# Business Name:  Farmbird Category:  Chicken Shop Rating:  5 Block:  600 - 699 block of h street ne Offense:  theft/other Offense Group:  property
# Business Name:  Farmbird Category:  Chicken Shop Rating:  5 Block:  600 - 699 block of h street ne Offense:  theft/other Offense Group:  property
# Business Name:  Farmbird Category:  Chicken Shop Rating:  5 Block:  600 - 699 block of h street ne Offense:  theft/other Offense Group:  property
# Business Name:  Farmbird Category:  Chicken Shop Rating:  5 Block:  600 - 699 block of h street ne Offense:  theft/other Offense Group:  property
# ...
# Business Name:  Tiki Taco Category:  Tacos Rating:  4.5 Block:  100 - 299 block of p street nw Offense:  theft f/auto Offense Group:  property
# Business Name:  Tiki Taco Category:  Tacos Rating:  4.5 Block:  100 - 299 block of p street nw Offense:  theft f/auto Offense Group:  property
# Business Name:  Tiki Taco Category:  Tacos Rating:  4.5 Block:  1 - 99 block of p street nw Offense:  theft f/auto Offense Group:  property
# Business Name:  Tiki Taco Category:  Tacos Rating:  4.5 Block:  100 - 299 block of p street nw Offense:  theft f/auto Offense Group:  property
# Business Name:  Tiki Taco Category:  Tacos Rating:  4.5 Block:  100 - 299 block of p street nw Offense:  theft/other Offense Group:  property
# Business Name:  Tiki Taco Category:  Tacos Rating:  4.5 Block:  100 - 299 block of p street nw Offense:  theft/other Offense Group:  property
# Business Name:  Tiki Taco Category:  Tacos Rating:  4.5 Block:  100 - 299 block of p street nw Offense:  theft/other Offense Group:  property
# Business Name:  Tiki Taco Category:  Tacos Rating:  4.5 Block:  1 - 99 block of p street nw Offense:  theft/other Offense Group:  property
# Business Name:  Tiki Taco Category:  Tacos Rating:  4.5 Block:  100 - 299 block of p street nw Offense:  theft/other Offense Group:  property
# Business Name:  Tiki Taco Category:  Tacos Rating:  4.5 Block:  1 - 99 block of p street nw Offense:  theft/other Offense Group:  property
# Business Name:  Tiki Taco Category:  Tacos Rating:  4.5 Block:  100 - 299 block of p street nw Offense:  theft/other Offense Group:  property
# Business Name:  Tiki Taco Category:  Tacos Rating:  4.5 Block:  2000 - 2016 block of p street nw Offense:  theft/other Offense Group:  property
# Business Name:  Tiki Taco Category:  Tacos Rating:  4.5 Block:  1 - 99 block of p street nw Offense:  theft/other Offense Group:  property
# Business Name:  Tiki Taco Category:  Tacos Rating:  4.5 Block:  1 - 99 block of p street nw Offense:  theft/other Offense Group:  property
# Business Name:  Tiki Taco Category:  Tacos Rating:  4.5 Block:  2000 - 2016 block of p street nw Offense:  theft/other Offense Group:  property
# Business Name:  Tiki Taco Category:  Tacos Rating:  4.5 Block:  1 - 99 block of p street nw Offense:  theft/other Offense Group:  property
# Business Name:  Tiki Taco Category:  Tacos Rating:  4.5 Block:  100 - 299 block of p street nw Offense:  theft/other Offense Group:  property
# Business Name:  Tiki Taco Category:  Tacos Rating:  4.5 Block:  100 - 299 block of p street nw Offense:  theft/other Offense Group:  property
# Business Name:  Tiki Taco Category:  Tacos Rating:  4.5 Block:  100 - 299 block of p street nw Offense:  theft/other Offense Group:  property
# Business Name:  Tiki Taco Category:  Tacos Rating:  4.5 Block:  100 - 299 block of p street nw Offense:  theft/other Offense Group:  property
# Business Name:  Tiki Taco Category:  Tacos Rating:  4.5 Block:  1 - 99 block of p street nw Offense:  theft/other Offense Group:  property
# Business Name:  Tiki Taco Category:  Tacos Rating:  4.5 Block:  2000 - 2016 block of p street nw Offense:  theft/other Offense Group:  property
# Business Name:  Tiki Taco Category:  Tacos Rating:  4.5 Block:  2000 - 2016 block of p street nw Offense:  theft/other Offense Group:  property
# Business Name:  Tiki Taco Category:  Tacos Rating:  4.5 Block:  100 - 299 block of p street nw Offense:  theft/other Offense Group:  property
# Business Name:  Tiki Taco Category:  Tacos Rating:  4.5 Block:  100 - 299 block of p street nw Offense:  theft/other Offense Group:  property
# Business Name:  Unconventional Diner Category:  Diners Rating:  4.5 Block:  1200 - 1299 block of 9th street nw Offense:  assault w/dangerous weapon Offense Group:  violent
# Business Name:  Unconventional Diner Category:  Diners Rating:  4.5 Block:  1200 - 1299 block of 9th street nw Offense:  assault w/dangerous weapon Offense Group:  violent
# Business Name:  Unconventional Diner Category:  Diners Rating:  4.5 Block:  1200 - 1299 block of 9th street nw Offense:  burglary Offense Group:  property
# Business Name:  Unconventional Diner Category:  Diners Rating:  4.5 Block:  1200 - 1299 block of 9th street nw Offense:  motor vehicle theft Offense Group:  property
# Business Name:  Unconventional Diner Category:  Diners Rating:  4.5 Block:  1200 - 1299 block of 9th street nw Offense:  robbery Offense Group:  violent
# Business Name:  Unconventional Diner Category:  Diners Rating:  4.5 Block:  1200 - 1299 block of 9th street nw Offense:  robbery Offense Group:  violent
# Business Name:  Unconventional Diner Category:  Diners Rating:  4.5 Block:  1200 - 1299 block of 9th street nw Offense:  theft f/auto Offense Group:  property
# Business Name:  Unconventional Diner Category:  Diners Rating:  4.5 Block:  1200 - 1299 block of 9th street nw Offense:  theft f/auto Offense Group:  property
# Business Name:  Unconventional Diner Category:  Diners Rating:  4.5 Block:  1200 - 1299 block of 9th street nw Offense:  theft f/auto Offense Group:  property
# Business Name:  Unconventional Diner Category:  Diners Rating:  4.5 Block:  1200 - 1299 block of 9th street nw Offense:  theft f/auto Offense Group:  property
# Business Name:  Unconventional Diner Category:  Diners Rating:  4.5 Block:  1200 - 1299 block of 9th street nw Offense:  theft f/auto Offense Group:  property
# Business Name:  Unconventional Diner Category:  Diners Rating:  4.5 Block:  1200 - 1299 block of 9th street nw Offense:  theft f/auto Offense Group:  property
# Business Name:  Unconventional Diner Category:  Diners Rating:  4.5 Block:  1200 - 1299 block of 9th street nw Offense:  theft f/auto Offense Group:  property
# Business Name:  Unconventional Diner Category:  Diners Rating:  4.5 Block:  1200 - 1299 block of 9th street nw Offense:  theft f/auto Offense Group:  property
# Business Name:  Unconventional Diner Category:  Diners Rating:  4.5 Block:  1200 - 1299 block of 9th street nw Offense:  theft f/auto Offense Group:  property
# Business Name:  Unconventional Diner Category:  Diners Rating:  4.5 Block:  1200 - 1299 block of 9th street nw Offense:  theft f/auto Offense Group:  property
# Business Name:  Unconventional Diner Category:  Diners Rating:  4.5 Block:  1200 - 1299 block of 9th street nw Offense:  theft f/auto Offense Group:  property
# Business Name:  Unconventional Diner Category:  Diners Rating:  4.5 Block:  1200 - 1299 block of 9th street nw Offense:  theft f/auto Offense Group:  property
# Business Name:  Unconventional Diner Category:  Diners Rating:  4.5 Block:  1200 - 1299 block of 9th street nw Offense:  theft f/auto Offense Group:  property
# Business Name:  Unconventional Diner Category:  Diners Rating:  4.5 Block:  1200 - 1299 block of 9th street nw Offense:  theft f/auto Offense Group:  property
# Business Name:  Unconventional Diner Category:  Diners Rating:  4.5 Block:  1200 - 1299 block of 9th street nw Offense:  theft f/auto Offense Group:  property
# Business Name:  Unconventional Diner Category:  Diners Rating:  4.5 Block:  1200 - 1299 block of 9th street nw Offense:  theft f/auto Offense Group:  property
# Business Name:  Unconventional Diner Category:  Diners Rating:  4.5 Block:  1200 - 1299 block of 9th street nw Offense:  theft f/auto Offense Group:  property
# Business Name:  Unconventional Diner Category:  Diners Rating:  4.5 Block:  1200 - 1299 block of 9th street nw Offense:  theft f/auto Offense Group:  property
# Business Name:  Unconventional Diner Category:  Diners Rating:  4.5 Block:  1200 - 1299 block of 9th street nw Offense:  theft f/auto Offense Group:  property
# Business Name:  Unconventional Diner Category:  Diners Rating:  4.5 Block:  1200 - 1299 block of 9th street nw Offense:  theft f/auto Offense Group:  property
# Business Name:  Unconventional Diner Category:  Diners Rating:  4.5 Block:  1200 - 1299 block of 9th street nw Offense:  theft f/auto Offense Group:  property
# Business Name:  Unconventional Diner Category:  Diners Rating:  4.5 Block:  1200 - 1299 block of 9th street nw Offense:  theft f/auto Offense Group:  property
# Business Name:  Unconventional Diner Category:  Diners Rating:  4.5 Block:  1200 - 1299 block of 9th street nw Offense:  theft f/auto Offense Group:  property
# Business Name:  Unconventional Diner Category:  Diners Rating:  4.5 Block:  1200 - 1299 block of 9th street nw Offense:  theft f/auto Offense Group:  property
# Business Name:  Unconventional Diner Category:  Diners Rating:  4.5 Block:  1200 - 1299 block of 9th street nw Offense:  theft f/auto Offense Group:  property
# Business Name:  Unconventional Diner Category:  Diners Rating:  4.5 Block:  1200 - 1299 block of 9th street nw Offense:  theft f/auto Offense Group:  property
# Business Name:  Unconventional Diner Category:  Diners Rating:  4.5 Block:  1200 - 1299 block of 9th street nw Offense:  theft f/auto Offense Group:  property
# Business Name:  Unconventional Diner Category:  Diners Rating:  4.5 Block:  1200 - 1299 block of 9th street nw Offense:  theft f/auto Offense Group:  property
# Business Name:  Unconventional Diner Category:  Diners Rating:  4.5 Block:  1200 - 1299 block of 9th street nw Offense:  theft f/auto Offense Group:  property
# Business Name:  Unconventional Diner Category:  Diners Rating:  4.5 Block:  1200 - 1299 block of 9th street nw Offense:  theft f/auto Offense Group:  property
# Business Name:  Unconventional Diner Category:  Diners Rating:  4.5 Block:  1200 - 1299 block of 9th street nw Offense:  theft f/auto Offense Group:  property
# Business Name:  Unconventional Diner Category:  Diners Rating:  4.5 Block:  1200 - 1299 block of 9th street nw Offense:  theft f/auto Offense Group:  property
# Business Name:  Unconventional Diner Category:  Diners Rating:  4.5 Block:  1200 - 1299 block of 9th street nw Offense:  theft f/auto Offense Group:  property
# Business Name:  Unconventional Diner Category:  Diners Rating:  4.5 Block:  1200 - 1299 block of 9th street nw Offense:  theft f/auto Offense Group:  property
# Business Name:  Unconventional Diner Category:  Diners Rating:  4.5 Block:  1200 - 1299 block of 9th street nw Offense:  theft f/auto Offense Group:  property
# Business Name:  Unconventional Diner Category:  Diners Rating:  4.5 Block:  1200 - 1299 block of 9th street nw Offense:  theft f/auto Offense Group:  property
# Business Name:  Unconventional Diner Category:  Diners Rating:  4.5 Block:  1200 - 1299 block of 9th street nw Offense:  theft f/auto Offense Group:  property
# Business Name:  Unconventional Diner Category:  Diners Rating:  4.5 Block:  1200 - 1299 block of 9th street nw Offense:  theft f/auto Offense Group:  property
# Business Name:  Unconventional Diner Category:  Diners Rating:  4.5 Block:  1200 - 1299 block of 9th street nw Offense:  theft f/auto Offense Group:  property
# Business Name:  Unconventional Diner Category:  Diners Rating:  4.5 Block:  1200 - 1299 block of 9th street nw Offense:  theft f/auto Offense Group:  property
# Business Name:  Unconventional Diner Category:  Diners Rating:  4.5 Block:  1200 - 1299 block of 9th street nw Offense:  theft f/auto Offense Group:  property
# Business Name:  Unconventional Diner Category:  Diners Rating:  4.5 Block:  1200 - 1299 block of 9th street nw Offense:  theft f/auto Offense Group:  property
# Business Name:  Unconventional Diner Category:  Diners Rating:  4.5 Block:  1200 - 1299 block of 9th street nw Offense:  theft f/auto Offense Group:  property
# Business Name:  Unconventional Diner Category:  Diners Rating:  4.5 Block:  1200 - 1299 block of 9th street nw Offense:  theft f/auto Offense Group:  property
# Business Name:  Unconventional Diner Category:  Diners Rating:  4.5 Block:  1200 - 1299 block of 9th street nw Offense:  theft f/auto Offense Group:  property
# Business Name:  Unconventional Diner Category:  Diners Rating:  4.5 Block:  1200 - 1299 block of 9th street nw Offense:  theft f/auto Offense Group:  property
# Business Name:  Unconventional Diner Category:  Diners Rating:  4.5 Block:  1200 - 1299 block of 9th street nw Offense:  theft f/auto Offense Group:  property
# Business Name:  Unconventional Diner Category:  Diners Rating:  4.5 Block:  1200 - 1299 block of 9th street nw Offense:  theft f/auto Offense Group:  property
# Business Name:  Unconventional Diner Category:  Diners Rating:  4.5 Block:  1200 - 1299 block of 9th street nw Offense:  theft f/auto Offense Group:  property
# Business Name:  Unconventional Diner Category:  Diners Rating:  4.5 Block:  1200 - 1299 block of 9th street nw Offense:  theft f/auto Offense Group:  property
# Business Name:  Unconventional Diner Category:  Diners Rating:  4.5 Block:  1200 - 1299 block of 9th street nw Offense:  theft f/auto Offense Group:  property
# Business Name:  Unconventional Diner Category:  Diners Rating:  4.5 Block:  1200 - 1299 block of 9th street nw Offense:  theft f/auto Offense Group:  property
# Business Name:  Unconventional Diner Category:  Diners Rating:  4.5 Block:  1200 - 1299 block of 9th street nw Offense:  theft f/auto Offense Group:  property
# Business Name:  Unconventional Diner Category:  Diners Rating:  4.5 Block:  1200 - 1299 block of 9th street nw Offense:  theft f/auto Offense Group:  property
# Business Name:  Unconventional Diner Category:  Diners Rating:  4.5 Block:  1200 - 1299 block of 9th street nw Offense:  theft f/auto Offense Group:  property
# Business Name:  Unconventional Diner Category:  Diners Rating:  4.5 Block:  1200 - 1299 block of 9th street nw Offense:  theft f/auto Offense Group:  property
# Business Name:  Unconventional Diner Category:  Diners Rating:  4.5 Block:  1200 - 1299 block of 9th street nw Offense:  theft f/auto Offense Group:  property
# Business Name:  Unconventional Diner Category:  Diners Rating:  4.5 Block:  1200 - 1299 block of 9th street nw Offense:  theft f/auto Offense Group:  property
# Business Name:  Unconventional Diner Category:  Diners Rating:  4.5 Block:  1200 - 1299 block of 9th street nw Offense:  theft f/auto Offense Group:  property
# Business Name:  Unconventional Diner Category:  Diners Rating:  4.5 Block:  1200 - 1299 block of 9th street nw Offense:  theft f/auto Offense Group:  property
# Business Name:  Unconventional Diner Category:  Diners Rating:  4.5 Block:  1200 - 1299 block of 9th street nw Offense:  theft/other Offense Group:  property
# Business Name:  Unconventional Diner Category:  Diners Rating:  4.5 Block:  1200 - 1299 block of 9th street nw Offense:  theft/other Offense Group:  property
# Business Name:  Unconventional Diner Category:  Diners Rating:  4.5 Block:  1200 - 1299 block of 9th street nw Offense:  theft/other Offense Group:  property
# Business Name:  Unconventional Diner Category:  Diners Rating:  4.5 Block:  1200 - 1299 block of 9th street nw Offense:  theft/other Offense Group:  property
# Business Name:  Unconventional Diner Category:  Diners Rating:  4.5 Block:  1200 - 1299 block of 9th street nw Offense:  theft/other Offense Group:  property
# Business Name:  Unconventional Diner Category:  Diners Rating:  4.5 Block:  1200 - 1299 block of 9th street nw Offense:  theft/other Offense Group:  property
# Business Name:  Unconventional Diner Category:  Diners Rating:  4.5 Block:  1200 - 1299 block of 9th street nw Offense:  theft/other Offense Group:  property
# Business Name:  Unconventional Diner Category:  Diners Rating:  4.5 Block:  1200 - 1299 block of 9th street nw Offense:  theft/other Offense Group:  property
# Business Name:  Unconventional Diner Category:  Diners Rating:  4.5 Block:  1200 - 1299 block of 9th street nw Offense:  theft/other Offense Group:  property
# Business Name:  Unconventional Diner Category:  Diners Rating:  4.5 Block:  1200 - 1299 block of 9th street nw Offense:  theft/other Offense Group:  property
# Business Name:  Unconventional Diner Category:  Diners Rating:  4.5 Block:  1200 - 1299 block of 9th street nw Offense:  theft/other Offense Group:  property
# Business Name:  Unconventional Diner Category:  Diners Rating:  4.5 Block:  1200 - 1299 block of 9th street nw Offense:  theft/other Offense Group:  property

# %%
loc_crimes=pd.read_csv("location_crime_20180424.csv",parse_dates=['report_date'])
loc_crimes.head()
# Out:
#   business_name                  address      category01  rating  \
# 0        Barrel  613 Pennsylvania Ave SE  American (New)     4.5
# 1        Barrel  613 Pennsylvania Ave SE  American (New)     4.5
# 2        Barrel  613 Pennsylvania Ave SE  American (New)     4.5
# 3        Barrel  613 Pennsylvania Ave SE  American (New)     4.5
# 4        Barrel  613 Pennsylvania Ave SE  American (New)     4.5
#
#                                        block                     offense  \
# 0  600 - 669 block of pennsylvania avenue se  assault w/dangerous weapon
# 1  600 - 669 block of pennsylvania avenue se  assault w/dangerous weapon
# 2  600 - 669 block of pennsylvania avenue se  assault w/dangerous weapon
# 3  600 - 669 block of pennsylvania avenue se                    burglary
# 4  600 - 669 block of pennsylvania avenue se                    burglary
#
#   offense_group  method  ucrrank  year         report_date
# 0       violent     gun        3  2018 2018-01-21 06:17:06
# 1       violent  others        3  2016 2016-08-11 15:29:31
# 2       violent   knife        3  2016 2016-06-21 05:20:36
# 3      property  others        5  2017 2017-06-06 17:01:14
# 4      property  others        5  2016 2016-08-10 08:30:50

# %%
loc_crimes.describe()
# Out:
#            rating     ucrrank         year
# count  588.000000  588.000000   588.000000
# mean     4.665816    6.119048  2016.693878
# std      0.235600    0.742557     0.640616
# min      4.500000    3.000000  2016.000000
# 25%      4.500000    6.000000  2016.000000
# 50%      4.500000    6.000000  2017.000000
# 75%      5.000000    6.000000  2017.000000
# max      5.000000    8.000000  2018.000000

# %%
loc_crimes['ucrrank'].describe()
# Out:
# count    588.000000
# mean       6.119048
# std        0.742557
# min        3.000000
# 25%        6.000000
# 50%        6.000000
# 75%        6.000000
# max        8.000000
# Name: ucrrank, dtype: float64

# %%
loc_crimes.dtypes
# Out:
# business_name            object
# address                  object
# category01               object
# rating                  float64
# block                    object
# offense                  object
# offense_group            object
# method                   object
# ucrrank                   int64
# year                      int64
# report_date      datetime64[ns]
# dtype: object

# %%
businesses = loc_crimes[['business_name','offense','ucrrank','report_date']]
businesses.head(20)
# Out:
#    business_name                     offense  ucrrank         report_date
# 0         Barrel  assault w/dangerous weapon        3 2018-01-21 06:17:06
# 1         Barrel  assault w/dangerous weapon        3 2016-08-11 15:29:31
# 2         Barrel  assault w/dangerous weapon        3 2016-06-21 05:20:36
# 3         Barrel                    burglary        5 2017-06-06 17:01:14
# 4         Barrel                    burglary        5 2016-08-10 08:30:50
# 5         Barrel                    burglary        5 2016-07-05 17:39:03
# 6         Barrel                    burglary        5 2016-06-10 01:12:42
# 7         Barrel         motor vehicle theft        8 2018-01-10 06:48:18
# 8         Barrel         motor vehicle theft        8 2017-06-10 01:15:58
# 9         Barrel                     robbery        4 2018-02-07 04:22:05
# 10        Barrel                     robbery        4 2017-08-26 17:54:36
# 11        Barrel                     robbery        4 2017-08-25 21:32:38
# 12        Barrel                     robbery        4 2017-04-26 00:18:04
# 13        Barrel                     robbery        4 2017-04-14 02:58:03
# 14        Barrel                     robbery        4 2017-02-08 07:46:55
# 15        Barrel                     robbery        4 2016-11-15 20:14:38
# 16        Barrel                     robbery        4 2016-07-23 17:24:47
# 17        Barrel                theft f/auto        7 2018-02-08 02:21:33
# 18        Barrel                theft f/auto        7 2017-12-11 03:58:44
# 19        Barrel                theft f/auto        7 2017-12-03 19:22:04

# %%
business_group = businesses.groupby('business_name')
business_group.size()
# Out:
# business_name
# Barrel                  176
# Farmbird                195
# Grady's                  15
# Honeysuckle              17
# Napoli Pasta Bar         14
# Rose's Luxury            43
# The Alibi                 2
# Tiki Taco                48
# Unconventional Diner     78
# dtype: int64

# %%
ucrrank_mean = business_group.mean()
ucrrank_mean.sort_values(by='ucrrank').head()
# Out:
#                 ucrrank
# business_name
# Barrel         5.892045
# Grady's        5.933333
# Farmbird       6.061538
# Rose's Luxury  6.069767
# Honeysuckle    6.176471

# %%
my_plot = ucrrank_mean.plot(kind='bar')

# %%
my_plot = ucrrank_mean.sort_values(by='ucrrank',ascending=False).plot(kind='bar',legend=None,title="Average UCR Rank by Business")
my_plot.set_xlabel("Businesses")
my_plot.set_ylabel("UCR Rank (1-9)")
# Out:
# Text(0,0.5,'UCR Rank (1-9)')
